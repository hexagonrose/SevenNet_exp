# %%
import torch
import e3nn
from torch.utils.cpp_extension import load
import json
import matplotlib.pyplot as plt
import itertools
import os

# %%
os.environ['TORCH_CUDA_ARCH_LIST'] = "8.0"
# os.environ["MAX_JOBS"] = "16"
sptp = load(name='sptp_linear', sources=['/home2/lsy/mdsim/fused_e3nn/fused_e3nn_kernel/sptp_linear.cpp','/home2/lsy/mdsim/fused_e3nn/fused_e3nn_kernel/sptp_linear.cu'], extra_cuda_cflags=["-lineinfo"], verbose=True)
# Out:
# Using /home2/lsy/.cache/torch_extensions/py311_cu124 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home2/lsy/.cache/torch_extensions/py311_cu124/sptp_linear/build.ninja...
# Building extension module sptp_linear...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module sptp_linear...

# %%
def mul_Irreps(mul, i_in):
    dd = []
    for ori_mul, ir in i_in:
        dd.append((ori_mul*mul, (ir.l, ir.p)))
    return e3nn.o3.Irreps(dd)
def compare(a, b):
    isclose = torch.isclose(a, b)
    diff_pos = torch.argwhere(isclose == False)
    for pos in diff_pos:
        pos_t = [x for x in pos]
        if(abs(a[pos_t] - b[pos_t]) > 1e-7):
            print(pos)
            print(a[pos_t] - b[pos_t] )
            
IR_IN1_IDX = 0
IR_IN2_IDX = 1
IR_OUT_IDX = 2
INST_IDX = 3

def load_nequip_config(h, l_max, layer_idx):
    filename = f"/home2/lsy/mdsim/nequip/benchmark_config/4_{h}_{l_max}_p_sc.txt"
    with open(filename, "r") as f:
        f_in = f.read().split("\n")

    per_layer_dict = dict()
    for l_idx, d in enumerate(f_in):
        if(d == "") : continue
        dd = json.loads(d)
        per_layer_dict[l_idx] = dd
    tp_list = per_layer_dict[layer_idx]["tp"]
    i_in1 = e3nn.o3.Irreps(tp_list[IR_IN1_IDX])
    i_in2 = e3nn.o3.Irreps(tp_list[IR_IN2_IDX])
    i_out = e3nn.o3.Irreps(tp_list[IR_OUT_IDX])
    inst_tuple = [tuple(x) for x in tp_list[INST_IDX]]

    return i_in1, i_in2, i_out, inst_tuple

# %%
def to_cuda_list(*arg, input_dtype = torch.float32):
    return_list = []
    for item in arg:
        if(type(item) == torch.Tensor):
            return_list.append(item.to(device="cuda"))
        else:
            return_list.append(torch.tensor(item,device="cuda", dtype=input_dtype))
    return return_list

def to_cuda_dict(strname_list, *arg):
    return_dict = {}
    for item,name in zip(arg,strname_list):
        if(type(item) == torch.Tensor):
            return_dict[name] = item.to("cuda")
        else:
            return_dict[name] = torch.tensor(item,device="cuda")
    return return_dict

def cumsum_list(s, np1 = True):
    new_s = []
    current = 0
    for e in s:
        new_s.append(current)
        current += e
    if(np1):
        new_s.append(current)
    return new_s

# %%
torch.manual_seed(0)

h = 32
l_max = 2
layer_idx = 3
batch_size = 4096
i_in1, i_in2, i_out, inst_tuple = load_nequip_config(h,l_max,layer_idx)
# i_in2 = mul_Irreps(3, i_in2)

uvuv_tp = e3nn.o3.FullTensorProduct(i_in1,i_in2, filter_ir_out=i_out, path_normalization="none", normalization="none")
uvuv_i_out = uvuv_tp.irreps_out

# ex_uvu_weight = e3nn.o3.experimental.FullTensorProductv2(i_in1, i_in2, filter_ir_out=i_out, irrep_normalization=None, regroup_output=False)
split_size = []
reshape_size = []
for inst in uvuv_tp.instructions:
    split_size.append(uvuv_i_out[inst.i_out].dim)
    reshape_size.append([inst.path_shape[0],inst.path_shape[1],uvuv_i_out[inst.i_out][1].dim])
weight_mul = e3nn.o3.experimental.FullTensorProduct_uvu_weight_only(i_in1, i_in2, split_size, reshape_size, filter_ir_out=i_out, irrep_normalization=None, regroup_output=False)

# uvw
# i_out = e3nn.o3.Irreps(tp_list[IR_OUT_IDX])
# tp = e3nn.o3.FullyConnectedTensorProduct(i_in1,i_in2,i_out,shared_weights=False, internal_weights=False)

# # uvu
tp = e3nn.o3.TensorProduct(i_in1,i_in2,i_out,inst_tuple,shared_weights=False, internal_weights=False, path_normalization="none", normalization="none") #
# Out:
# /home2/lsy/miniconda3/envs/cueq/lib/python3.11/site-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /home2/lsy/miniconda3/envs/cueq/lib/python3.11/site-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(

# %%
# full tp -> linear
# i_out = full_tp.irreps_out
unique_cg = []
nnz_cg_cnt = 0
all_cg_cnt = 0
cg_dummy = torch.zeros(i_in1.dim, i_in2.dim, uvuv_i_out.dim)
cg_dummy_coverage = torch.zeros(i_in1.dim, i_in2.dim, uvuv_i_out.dim)
for inst in uvuv_tp.instructions:
    i = inst.i_in1
    j = inst.i_in2
    k = inst.i_out

    mul_in1, ir_in1 = i_in1[i]
    mul_in2, ir_in2 = i_in2[j]
    mul_out, ir_out = uvuv_i_out[k]

    cg = e3nn.o3.wigner_3j(ir_in1.l, ir_in2.l, ir_out.l)
    unique_cg += list(cg.unique())
    all_cg_cnt+= cg.numel()
    nnz_cg_cnt += cg.count_nonzero()

    partial_mat_cg = torch.zeros(i_in1[i].dim, i_in2[j].dim, uvuv_i_out[k].dim)
    
    ## uvuv
    for u,v in itertools.product(range(mul_in1), range(mul_in2)):
        partial_mat_cg [u*ir_in1.dim:(u+1)*ir_in1.dim,
        v*ir_in2.dim:(v+1)*ir_in2.dim,
        (u*mul_in2+v)*ir_out.dim:(u*mul_in2+v+1)*ir_out.dim] = cg 

    cg_dummy[i_in1.slices()[i], i_in2.slices()[j], uvuv_i_out.slices()[k]] = partial_mat_cg
    cg_dummy_coverage[i_in1.slices()[i], i_in2.slices()[j], uvuv_i_out.slices()[k]] = 1
print("compute density", nnz_cg_cnt / all_cg_cnt)
# Out:
# compute density tensor(0.2228)

# %%
cg_dummy_kij = cg_dummy.permute(2,0,1)
cg_dummy_kij_flat = cg_dummy_kij.reshape(uvuv_i_out.dim, -1)
# cg_kij_pos_tuple = cg_dummy_kij.nonzero(as_tuple=True)
# cg_kij_pos_feed = cg_dummy_kij.nonzero().to(dtype=torch.int32).contiguous()
# cg_kij_val_feed = cg_dummy_kij[cg_kij_pos_tuple]
per_out_fiber = cg_dummy_kij_flat.count_nonzero(dim=1)
unique_cg_lookup = list(set([x.item() for x in unique_cg]))

uni_cg_cnt = len(unique_cg_lookup)
out_size = uvuv_i_out.dim

# %%
in1 = torch.rand(batch_size, i_in1.dim)
in2 = torch.rand(batch_size, i_in2.dim)
out = torch.zeros((batch_size,uvuv_i_out.dim))

uni_w3j = torch.tensor(unique_cg_lookup)

if(tp.shared_weights):
    weight = torch.rand(tp.weight_numel)
else:
    weight = torch.rand(batch_size,tp.weight_numel)
    # weight = torch.ones(batch_size,tp.weight_numel)

    # wrong_weight = torch.ones(batch_size,tp.weight_numel)
    # # weight[0,:] = torch.arange(weight.shape[1])
    # wrong_weight[:,834] = 2.45
    # weight[:,834] = 2.45

    # weight[:,500:532] = 4.45

path_weight = torch.zeros(i_out.dim) 
for inst in tp.instructions:
    k = inst.i_out
    path_weight[i_out.slices()[k]] = inst.path_weight

# %%
w_idx = 0
cnt = 0
blk_size = 32
perout_w_idx = []
per_blk_k_dim = []

for mul,ir in i_out:
    for _ in range(mul):
        for i in range(ir.dim):
            cnt+=1
            perout_w_idx.append(w_idx)
            if(cnt%32==0):
                per_blk_k_dim.append(ir.dim)
        w_idx+=1

# %%
weight_sptp = []
for inst_idx in weight_mul.inv:
    u,v, slice = weight_mul.weight_uv_pair_sorted_slice[inst_idx]
    weight_sptp.append(weight[:,slice])
weight_sptp = torch.cat(weight_sptp,dim=1)

# %%
blk_u_in1_idx = []
blk_u_in2_idx = []

per_blk_w_start_idx = []
per_blk_w_end_idx = []
per_blk_w_precnt = []

per_blk_u_in1_idx_range = []
per_blk_u_in2_idx_range = []
per_blk_fiber_start_range = []

per_fiber_local_idx = []
per_fiber_global_idx = []

max_u_in1_dim = 0
max_u_in2_dim = 0 
max_fiber_cnt = 0

pattern_len_array = []
stride_mul_array = []
rem_cum_idx_array = []
rem_cumval_array = []
fiber_cnt_array = []

step = 32
i = 0
prev_w_idx_cnt = 0
prev_idx = -1

while(i< uvuv_i_out.dim):
    local_k_idx = cg_dummy_kij[i:i+step].nonzero()[:,0]
    blk_in1_idx = cg_dummy_kij[i:i+step].nonzero()[:,1]
    blk_in2_idx = cg_dummy_kij[i:i+step].nonzero()[:,2]

    used_weight_idx = perout_w_idx[i:i+step]

    per_blk_w_start_idx.append(used_weight_idx[0])
    per_blk_w_end_idx.append(used_weight_idx[-1]+1)
    
    if (prev_idx == used_weight_idx[0]):
        per_blk_w_precnt.append(prev_w_idx_cnt)
    else:
        per_blk_w_precnt.append(0)
    prev_idx = used_weight_idx[-1]

    prev_w_idx_cnt=0
    for w_idx_val in used_weight_idx:
        if w_idx_val == used_weight_idx[-1]: prev_w_idx_cnt+=1

    u_in1_list = blk_in1_idx.unique().tolist()
    u_in2_list = blk_in2_idx.unique().tolist()

    max_u_in1_dim = max(max_u_in1_dim, len(u_in1_list))
    max_u_in2_dim = max(max_u_in2_dim, len(u_in2_list))
    max_fiber_cnt = max(max_fiber_cnt, len(blk_in1_idx))

    blk_u_in1_idx.append(u_in1_list)
    blk_u_in2_idx.append(u_in2_list)

    per_blk_u_in1_idx_range.append(len(u_in1_list))
    per_blk_u_in2_idx_range.append(len(u_in2_list))

    per_blk_fiber_start_range.append(len(blk_in1_idx))

    local_in1_idx = [u_in1_list.index(x.item()) for x in blk_in1_idx]
    local_in2_idx = [u_in2_list.index(x.item()) for x in blk_in2_idx]

    for l_a,l_b,l_k,g_a,g_b in zip(local_in1_idx,local_in2_idx, local_k_idx,blk_in1_idx,blk_in2_idx):
        real_k = i + l_k
        cg_idx = unique_cg_lookup.index(cg_dummy_kij[real_k,g_a,g_b])

        per_fiber_local_idx.append(l_a)
        per_fiber_local_idx.append(l_b)
        per_fiber_local_idx.append(cg_idx)
        per_fiber_local_idx.append(l_k)

        per_fiber_global_idx.append(g_a)
        per_fiber_global_idx.append(g_b)
        per_fiber_global_idx.append(cg_idx)
        per_fiber_global_idx.append(real_k)


    pattern = per_out_fiber[i:i+step].tolist()
    pattern_length = 0
    if ([pattern[0]]*len(pattern) == pattern):
        pattern_length=1
    elif (list(itertools.chain.from_iterable(([pattern[0:3]]*len(pattern))))[0:len(pattern)] == pattern):
        pattern_length=3
    elif (list(itertools.chain.from_iterable(([pattern[0:5]]*len(pattern))))[0:len(pattern)] == pattern):
        pattern_length=5
    elif (list(itertools.chain.from_iterable(([pattern[0:7]]*len(pattern))))[0:len(pattern)] == pattern):
        pattern_length=7
    elif (list(itertools.chain.from_iterable(([pattern[0:9]]*len(pattern))))[0:len(pattern)] == pattern):
        pattern_length=9
    elif (list(itertools.chain.from_iterable(([pattern[0:11]]*len(pattern))))[0:len(pattern)] == pattern):
        pattern_length=11
    else:
        print(pattern, i)
        print("bad")

    unit_pattern = pattern[0:pattern_length]

    pattern_len_array.append(pattern_length)
    stride_mul_array.append(sum(unit_pattern))
    rem_cum_idx_array.append(pattern_length)

    rem_cumval_array.append(cumsum_list(unit_pattern, False))
    fiber_cnt_array.append(unit_pattern)

    i += step

rem_cum_idx_array = cumsum_list(rem_cum_idx_array,False)
per_blk_u_in1_idx_range  = cumsum_list(per_blk_u_in1_idx_range)
per_blk_u_in2_idx_range  = cumsum_list(per_blk_u_in2_idx_range)
per_blk_fiber_start_range = cumsum_list(per_blk_fiber_start_range)

rem_cumval_array = list(itertools.chain.from_iterable(rem_cumval_array))
fiber_cnt_array = list(itertools.chain.from_iterable(fiber_cnt_array))
blk_u_in1_idx = list(itertools.chain.from_iterable(blk_u_in1_idx))
blk_u_in2_idx = list(itertools.chain.from_iterable(blk_u_in2_idx))

per_fiber_local_idx = torch.tensor(per_fiber_local_idx).to(torch.uint8)
per_fiber_global_idx = torch.tensor(per_fiber_global_idx)

# %%
READ_IDX = 0
WRITE_IDX = 1
MUL_FLOPS_IDX = 2
ADD_FLOPS_IDX = 3
def total_flops(input):
    return input[MUL_FLOPS_IDX] + input[ADD_FLOPS_IDX]
def total_MEM_traffic(input):
    return input[READ_IDX] + input[WRITE_IDX]

def compute_ai(AI_dict_item):
    return total_flops(AI_dict_item)/ total_MEM_traffic(AI_dict_item)

def time_estimate(AI_dict_item, FLOPS=20, MEM_BW=1.5):
    # in u sec
    ai = compute_ai(AI_dict_item)
    time = (total_flops(AI_dict_item)/10**12) / min(FLOPS, MEM_BW*ai)
    return time*(10**6)

# %%
def print_ai(batch_size , i_in1, i_in2, i_out, uvuv_tp, FLOPS=20, MEM_BW=1.5):
    # e3nn outer product
    # scale with z
    AI_dict= {"op":[0,0,0,0], "cg":[0,0,0,0], "wmul":[0,0,0,0]}

    z = batch_size
    outer_product_dict = {}

    for inst in uvuv_tp.instructions:
        u = i_in1[inst.i_in1].mul
        v = i_in2[inst.i_in2].mul

        i = i_in1[inst.i_in1][1].dim
        j = i_in2[inst.i_in2][1].dim
        k = i_out[inst.i_out][1].dim

        op_str = f"{inst.i_in1}_{inst.i_in2}"
        if(op_str not in outer_product_dict):
            outer_product_dict[op_str] = 1
            AI_dict["op"][READ_IDX] += (u*i + v*j) * z *4
            AI_dict["op"][WRITE_IDX] += u*i*v*j * z*4
            AI_dict["op"][MUL_FLOPS_IDX] += u*i*v*j * z            

        AI_dict["cg"][READ_IDX] += u*i*v*j * z*4
        AI_dict["cg"][READ_IDX] += i*j*k*4
        AI_dict["cg"][WRITE_IDX] += u*v*k * z*4
        AI_dict["cg"][MUL_FLOPS_IDX] += z*u*v*i*j*k
        AI_dict["cg"][ADD_FLOPS_IDX] += z*u*v*(i*j-1)*k

        AI_dict["wmul"][READ_IDX] += u*v*k * z*4
        AI_dict["wmul"][READ_IDX] += z*u*v*4
        AI_dict["wmul"][WRITE_IDX] += z* u*k*4
        
        AI_dict["wmul"][MUL_FLOPS_IDX] += z*u*v*k
        AI_dict["wmul"][ADD_FLOPS_IDX] += z*u*k*(v-1)

    op_ai = compute_ai(AI_dict["op"])
    cg_ai = compute_ai(AI_dict["cg"])
    w_ai = compute_ai(AI_dict["wmul"])
    return (op_ai, cg_ai, w_ai), (
        time_estimate(AI_dict["op"], FLOPS,MEM_BW), 
        time_estimate(AI_dict["cg"], FLOPS,MEM_BW), 
        time_estimate(AI_dict["wmul"],FLOPS,MEM_BW)), AI_dict

# %%
outs = print_ai(batch_size, i_in1, i_in2, i_out, uvuv_tp)

# %%
naive_read = [x[READ_IDX]/10**6 for x in outs[2].values()]
naive_write = [x[WRITE_IDX]/10**6 for x in outs[2].values()]

# %%
print(naive_read)
print(naive_write)
naive_total = sum(naive_write) + sum(naive_read)
# Out:
# [29.196288, 187.700024, 69.206016]
# [84.934656, 53.477376, 53.477376]

# %%
ideal_mem_traffic = [0,0,0,0]
real_mem_traffic = [0,0,0,0]
fp32_size = 4

# read in1 in2
ideal_mem_traffic[0] += (i_in1.dim + i_in2.dim) * batch_size * fp32_size
real_mem_traffic[0] += (len(blk_u_in1_idx) + len(blk_u_in2_idx)) * batch_size * fp32_size
# read weight
ideal_mem_traffic[1] += weight.numel() * fp32_size
real_mem_traffic[1] += sum(torch.tensor(per_blk_w_end_idx) - torch.tensor(per_blk_w_start_idx)).item() * batch_size * fp32_size

# metadata time
real_mem_traffic[2] += len(per_fiber_local_idx) * (batch_size /32)
# write traffic
real_mem_traffic[3] += out.numel()*fp32_size
ideal_mem_traffic[3] += out.numel()*fp32_size

# %%
print("ideal_mem_traffic ", sum(ideal_mem_traffic)/10**6 , "MB")
print("ideal_mem_traffic ", [x / 10**6 for x in ideal_mem_traffic] , "MB")

print("real_mem_traffic ", sum(real_mem_traffic)/10**6 , "MB")
print("real_mem_traffic ", [x / 10**6 for x in real_mem_traffic] , "MB")

print("naive_mem_traffic ", naive_total , "MB")
# Out:
# ideal_mem_traffic  78.790656 MB
# ideal_mem_traffic  [9.58464, 15.72864, 0.0, 53.477376] MB
# real_mem_traffic  137.166848 MB
# real_mem_traffic  [62.291968, 16.908288, 4.489216, 53.477376] MB
# naive_mem_traffic  477.99173600000006 MB

# %%
32 K
ideal_mem_traffic  1730.1504 MB
ideal_mem_traffic  [136.31488, 285.212672, 0.0, 1308.622848] MB
real_mem_traffic  3409.18272 MB
real_mem_traffic  [1623.195648, 317.19424, 160.169984, 1308.622848] MB
naive_mem_traffic  13103.033184 MB
# Out:
#   Cell In[19], line 1
#     32 K
#        ^
# SyntaxError: invalid syntax

# %%
other_meta = sum([len(x) for x in [per_blk_w_start_idx,
                    per_blk_w_end_idx,
                    per_blk_w_precnt,
                    per_blk_k_dim,

                    per_blk_u_in1_idx_range,
                    per_blk_u_in2_idx_range,
                    per_blk_fiber_start_range,
                    
                    pattern_len_array,
                    stride_mul_array,
                    rem_cum_idx_array,
                    rem_cumval_array,
                    fiber_cnt_array]]) * (batch_size/32) / 10**6

# %%
print(i_in1.dim, i_in2.dim)
print(len(blk_u_in1_idx))
print(len(blk_u_in2_idx))
# Out:
# 576 9
# 3444
# 358

# %%
per_fiber_local_idx
# Out:
# tensor([ 0,  0,  1,  ...,  0,  7, 31], dtype=torch.uint8)

# %%
print(len(per_fiber_local_idx))
# Out:
# 35072

# %%
# num_ z block 
half_size = 2
(len(per_blk_w_start_idx) + len(per_blk_w_end_idx) + len(per_blk_w_precnt) + len(per_blk_k_dim) + len(per_blk_u_in1_idx_range))* half_size 

# per block
# Out:
# 1022

# %%
# # Need to fix for u != 32
# per_blk_w_idx = []
# for w_idx, i in enumerate(uvuv_i_out):
#     for j in range(i.ir.dim):
#         # need to add u//32 time
#         # will need seperate w_idx counter 
#         per_blk_w_idx.append(w_idx)

# %%
out_cuda = out.to(device="cuda")
main1_cuda = to_cuda_list(in1.T.contiguous(),in2.T.contiguous())
main2_cuda = to_cuda_list(uni_w3j,weight_sptp.T.contiguous(),path_weight)
meta_cuda = to_cuda_list(
                    per_blk_w_start_idx,
                    per_blk_w_end_idx,
                    per_blk_w_precnt,
                    per_blk_k_dim,

                    per_blk_u_in1_idx_range,
                    per_blk_u_in2_idx_range,
                    per_blk_fiber_start_range,
                    
                    blk_u_in1_idx,
                    blk_u_in2_idx,

                    pattern_len_array,
                    stride_mul_array,
                    rem_cum_idx_array,
                    rem_cumval_array,
                    fiber_cnt_array, 
                    
                    per_fiber_local_idx,
                    input_dtype=torch.uint16)
size_input = [max_u_in1_dim,max_u_in2_dim,max_fiber_cnt,uni_cg_cnt]
size_input = [int(x) for x in size_input]

# %%
sptp.sptp_linear_v1(*main1_cuda, out_cuda, *main2_cuda,*meta_cuda,*size_input)

# %%
out_cuda
# Out:
# tensor([[ 0.0353,  0.0048,  0.0091,  ...,  0.0575,  0.0452, -0.0060],
#         [ 0.0990,  0.1063,  0.0881,  ..., -0.0040,  0.0010, -0.0073],
#         [ 0.1247,  0.0288,  0.0212,  ...,  0.0492, -0.0135,  0.0300],
#         ...,
#         [ 0.0707,  0.1817,  0.4029,  ...,  0.1425,  0.0968, -0.0146],
#         [ 0.1039,  0.3051,  0.0421,  ...,  0.0953, -0.0294,  0.0814],
#         [ 0.2821,  0.0105,  0.1127,  ...,  0.0288, -0.1635, -0.0489]],
#        device='cuda:0')

# %%
correct_out = tp(in1,in2,weight)

# %%
correct_out[0]
# Out:
# tensor([ 0.0353,  0.0048,  0.0091,  ...,  0.0575,  0.0452, -0.0060])

# %%
index = 0
torch.isclose(correct_out[index], out_cuda.cpu()[index]).all()
for a,b in zip(correct_out[index], out_cuda.cpu()[index]):
    print(torch.isclose(a,b),a,b)
# Out:
# tensor(True) tensor(0.0028) tensor(0.0028)
# tensor(True) tensor(0.0122) tensor(0.0122)
# tensor(True) tensor(0.0805) tensor(0.0805)
# tensor(True) tensor(0.1163) tensor(0.1163)
# tensor(True) tensor(0.1643) tensor(0.1643)
# tensor(True) tensor(0.0852) tensor(0.0852)
# tensor(True) tensor(0.0435) tensor(0.0435)
# tensor(True) tensor(0.1736) tensor(0.1736)
# tensor(True) tensor(0.2035) tensor(0.2035)
# tensor(True) tensor(0.3153) tensor(0.3153)
# tensor(True) tensor(0.0228) tensor(0.0228)
# tensor(True) tensor(0.2755) tensor(0.2755)
# tensor(True) tensor(0.1566) tensor(0.1566)
# tensor(True) tensor(0.0192) tensor(0.0192)
# tensor(True) tensor(0.1669) tensor(0.1669)
# tensor(True) tensor(0.0688) tensor(0.0688)
# tensor(True) tensor(0.0983) tensor(0.0983)
# tensor(True) tensor(0.1652) tensor(0.1652)
# tensor(True) tensor(0.0401) tensor(0.0401)
# tensor(True) tensor(0.0971) tensor(0.0971)
# tensor(True) tensor(0.3147) tensor(0.3147)
# tensor(True) tensor(0.2743) tensor(0.2743)
# tensor(True) tensor(0.0619) tensor(0.0619)
# tensor(True) tensor(0.0449) tensor(0.0449)
# tensor(True) tensor(0.0089) tensor(0.0089)
# tensor(True) tensor(0.0693) tensor(0.0693)
# tensor(True) tensor(0.0700) tensor(0.0700)
# tensor(True) tensor(0.0167) tensor(0.0167)
# tensor(True) tensor(0.0073) tensor(0.0073)
# tensor(True) tensor(0.3002) tensor(0.3002)
# tensor(True) tensor(0.1189) tensor(0.1189)
# tensor(True) tensor(0.0084) tensor(0.0084)
# tensor(True) tensor(0.0028) tensor(0.0028)
# tensor(True) tensor(0.0821) tensor(0.0821)
# tensor(True) tensor(0.1085) tensor(0.1085)
# tensor(True) tensor(0.3056) tensor(0.3056)
# tensor(True) tensor(0.1177) tensor(0.1177)
# tensor(True) tensor(0.0582) tensor(0.0582)
# tensor(True) tensor(0.4516) tensor(0.4516)
# tensor(True) tensor(0.0195) tensor(0.0195)
# tensor(True) tensor(0.3437) tensor(0.3437)
# tensor(True) tensor(0.1177) tensor(0.1177)
# tensor(True) tensor(0.3136) tensor(0.3136)
# tensor(True) tensor(0.0620) tensor(0.0620)
# tensor(True) tensor(0.5305) tensor(0.5305)
# tensor(True) tensor(0.2251) tensor(0.2251)
# tensor(True) tensor(0.3028) tensor(0.3028)
# tensor(True) tensor(0.3026) tensor(0.3026)
# tensor(True) tensor(0.0621) tensor(0.0621)
# tensor(True) tensor(0.1477) tensor(0.1477)
# tensor(True) tensor(0.1325) tensor(0.1325)
# tensor(True) tensor(0.5388) tensor(0.5388)
# tensor(True) tensor(0.0713) tensor(0.0713)
# tensor(True) tensor(0.4843) tensor(0.4843)
# tensor(True) tensor(0.4834) tensor(0.4834)
# tensor(True) tensor(0.1474) tensor(0.1474)
# tensor(True) tensor(0.6604) tensor(0.6604)
# tensor(True) tensor(0.2848) tensor(0.2848)
# tensor(True) tensor(0.0423) tensor(0.0423)
# tensor(True) tensor(0.1913) tensor(0.1913)
# tensor(True) tensor(0.3276) tensor(0.3276)
# tensor(True) tensor(0.1907) tensor(0.1907)
# tensor(True) tensor(0.2872) tensor(0.2872)
# tensor(True) tensor(0.3296) tensor(0.3296)
# tensor(True) tensor(0.1309) tensor(0.1309)
# tensor(True) tensor(0.2341) tensor(0.2341)
# tensor(True) tensor(0.1133) tensor(0.1133)
# tensor(True) tensor(0.2199) tensor(0.2199)
# tensor(True) tensor(0.3380) tensor(0.3380)
# tensor(True) tensor(0.2638) tensor(0.2638)
# tensor(True) tensor(0.1848) tensor(0.1848)
# tensor(True) tensor(0.3441) tensor(0.3441)
# tensor(True) tensor(0.0733) tensor(0.0733)
# tensor(True) tensor(0.0100) tensor(0.0100)
# tensor(True) tensor(0.1495) tensor(0.1495)
# tensor(True) tensor(0.4407) tensor(0.4407)
# tensor(True) tensor(0.1843) tensor(0.1843)
# tensor(True) tensor(0.3485) tensor(0.3485)
# tensor(True) tensor(0.2035) tensor(0.2035)
# tensor(True) tensor(0.2697) tensor(0.2697)
# tensor(True) tensor(0.2734) tensor(0.2734)
# tensor(True) tensor(0.1052) tensor(0.1052)
# tensor(True) tensor(0.1854) tensor(0.1854)
# tensor(True) tensor(0.2905) tensor(0.2905)
# tensor(True) tensor(0.1449) tensor(0.1449)
# tensor(True) tensor(0.4022) tensor(0.4022)
# tensor(True) tensor(0.4403) tensor(0.4403)
# tensor(True) tensor(0.1506) tensor(0.1506)
# tensor(True) tensor(0.2082) tensor(0.2082)
# tensor(True) tensor(0.3945) tensor(0.3945)
# tensor(True) tensor(0.2987) tensor(0.2987)
# tensor(True) tensor(0.5234) tensor(0.5234)
# tensor(True) tensor(0.2923) tensor(0.2923)
# tensor(True) tensor(0.3273) tensor(0.3273)
# tensor(True) tensor(0.1496) tensor(0.1496)
# tensor(True) tensor(0.0495) tensor(0.0495)
# tensor(True) tensor(0.0918) tensor(0.0918)
# tensor(True) tensor(0.0442) tensor(0.0442)
# tensor(True) tensor(0.0245) tensor(0.0245)
# tensor(True) tensor(0.1675) tensor(0.1675)
# tensor(True) tensor(0.0897) tensor(0.0897)
# tensor(True) tensor(0.1390) tensor(0.1390)
# tensor(True) tensor(0.0609) tensor(0.0609)
# tensor(True) tensor(0.1509) tensor(0.1509)
# tensor(True) tensor(0.4082) tensor(0.4082)
# tensor(True) tensor(0.4143) tensor(0.4143)
# tensor(True) tensor(0.0341) tensor(0.0341)
# tensor(True) tensor(0.2066) tensor(0.2066)
# tensor(True) tensor(0.0020) tensor(0.0020)
# tensor(True) tensor(0.1288) tensor(0.1288)
# tensor(True) tensor(0.0900) tensor(0.0900)
# tensor(True) tensor(0.0401) tensor(0.0401)
# tensor(True) tensor(0.0849) tensor(0.0849)
# tensor(True) tensor(0.2955) tensor(0.2955)
# tensor(True) tensor(0.0177) tensor(0.0177)
# tensor(True) tensor(0.0820) tensor(0.0820)
# tensor(True) tensor(0.0302) tensor(0.0302)
# tensor(True) tensor(0.1833) tensor(0.1833)
# tensor(True) tensor(0.1683) tensor(0.1683)
# tensor(True) tensor(0.0052) tensor(0.0052)
# tensor(True) tensor(0.2117) tensor(0.2117)
# tensor(True) tensor(0.0339) tensor(0.0339)
# tensor(True) tensor(0.1637) tensor(0.1637)
# tensor(True) tensor(0.1201) tensor(0.1201)
# tensor(True) tensor(0.1087) tensor(0.1087)
# tensor(True) tensor(0.0502) tensor(0.0502)
# tensor(True) tensor(0.1209) tensor(0.1209)
# tensor(True) tensor(0.0139) tensor(0.0139)
# tensor(True) tensor(0.4674) tensor(0.4674)
# tensor(True) tensor(0.2983) tensor(0.2983)
# tensor(True) tensor(0.2307) tensor(0.2307)
# tensor(True) tensor(0.0316) tensor(0.0316)
# tensor(True) tensor(0.1155) tensor(0.1155)
# tensor(True) tensor(0.0045) tensor(0.0045)
# tensor(True) tensor(0.0342) tensor(0.0342)
# tensor(True) tensor(0.1147) tensor(0.1147)
# tensor(True) tensor(0.5631) tensor(0.5631)
# tensor(True) tensor(0.1560) tensor(0.1560)
# tensor(True) tensor(0.0193) tensor(0.0193)
# tensor(True) tensor(0.1349) tensor(0.1349)
# tensor(True) tensor(0.5776) tensor(0.5776)
# tensor(True) tensor(0.3878) tensor(0.3878)
# tensor(True) tensor(0.0957) tensor(0.0957)
# tensor(True) tensor(0.1666) tensor(0.1666)
# tensor(True) tensor(0.5577) tensor(0.5577)
# tensor(True) tensor(0.1572) tensor(0.1572)
# tensor(True) tensor(0.4466) tensor(0.4466)
# tensor(True) tensor(0.0652) tensor(0.0652)
# tensor(True) tensor(0.5066) tensor(0.5066)
# tensor(True) tensor(0.1479) tensor(0.1479)
# tensor(True) tensor(0.1629) tensor(0.1629)
# tensor(True) tensor(0.4762) tensor(0.4762)
# tensor(True) tensor(0.2199) tensor(0.2199)
# tensor(True) tensor(0.5422) tensor(0.5422)
# tensor(True) tensor(0.2111) tensor(0.2111)
# tensor(True) tensor(0.4626) tensor(0.4626)
# tensor(True) tensor(0.7231) tensor(0.7231)
# tensor(True) tensor(0.4146) tensor(0.4146)
# tensor(True) tensor(0.3492) tensor(0.3492)
# tensor(True) tensor(0.0103) tensor(0.0103)
# tensor(True) tensor(0.3452) tensor(0.3452)
# tensor(True) tensor(0.2541) tensor(0.2541)
# tensor(True) tensor(0.2797) tensor(0.2797)
# tensor(True) tensor(0.0607) tensor(0.0607)
# tensor(True) tensor(0.1096) tensor(0.1096)
# tensor(True) tensor(0.0905) tensor(0.0905)
# tensor(True) tensor(0.1562) tensor(0.1562)
# tensor(True) tensor(0.0675) tensor(0.0675)
# tensor(True) tensor(0.0775) tensor(0.0775)
# tensor(True) tensor(0.3083) tensor(0.3083)
# tensor(True) tensor(0.2323) tensor(0.2323)
# tensor(True) tensor(0.0963) tensor(0.0963)
# tensor(True) tensor(0.3621) tensor(0.3621)
# tensor(True) tensor(0.0094) tensor(0.0094)
# tensor(True) tensor(0.0623) tensor(0.0623)
# tensor(True) tensor(0.2751) tensor(0.2751)
# tensor(True) tensor(0.0717) tensor(0.0717)
# tensor(True) tensor(0.0703) tensor(0.0703)
# tensor(True) tensor(0.3735) tensor(0.3735)
# tensor(True) tensor(0.3900) tensor(0.3900)
# tensor(True) tensor(0.1458) tensor(0.1458)
# tensor(True) tensor(0.2778) tensor(0.2778)
# tensor(True) tensor(0.1781) tensor(0.1781)
# tensor(True) tensor(0.1358) tensor(0.1358)
# tensor(True) tensor(0.1468) tensor(0.1468)
# tensor(True) tensor(0.4350) tensor(0.4350)
# tensor(True) tensor(0.2903) tensor(0.2903)
# tensor(True) tensor(0.1532) tensor(0.1532)
# tensor(True) tensor(0.2717) tensor(0.2717)
# tensor(True) tensor(0.2351) tensor(0.2351)
# tensor(True) tensor(0.5695) tensor(0.5695)
# tensor(True) tensor(0.1648) tensor(0.1648)
# tensor(True) tensor(0.1040) tensor(0.1040)
# tensor(True) tensor(0.0065) tensor(0.0065)
# tensor(True) tensor(0.1251) tensor(0.1251)
# tensor(True) tensor(0.1601) tensor(0.1601)
# tensor(True) tensor(0.0099) tensor(0.0099)
# tensor(True) tensor(0.1926) tensor(0.1926)
# tensor(True) tensor(0.0491) tensor(0.0491)
# tensor(True) tensor(0.0030) tensor(0.0030)
# tensor(True) tensor(0.0591) tensor(0.0591)
# tensor(True) tensor(0.2434) tensor(0.2434)
# tensor(True) tensor(0.0151) tensor(0.0151)
# tensor(True) tensor(0.2928) tensor(0.2928)
# tensor(True) tensor(0.1795) tensor(0.1795)
# tensor(True) tensor(0.0111) tensor(0.0111)
# tensor(True) tensor(0.2160) tensor(0.2160)
# tensor(True) tensor(0.1165) tensor(0.1165)
# tensor(True) tensor(0.0072) tensor(0.0072)
# tensor(True) tensor(0.1401) tensor(0.1401)
# tensor(True) tensor(0.1176) tensor(0.1176)
# tensor(True) tensor(0.0073) tensor(0.0073)
# tensor(True) tensor(0.1415) tensor(0.1415)
# tensor(True) tensor(0.0269) tensor(0.0269)
# tensor(True) tensor(0.0017) tensor(0.0017)
# tensor(True) tensor(0.0323) tensor(0.0323)
# tensor(True) tensor(0.1962) tensor(0.1962)
# tensor(True) tensor(0.0122) tensor(0.0122)
# tensor(True) tensor(0.2360) tensor(0.2360)
# tensor(True) tensor(0.0314) tensor(0.0314)
# tensor(True) tensor(0.0019) tensor(0.0019)
# tensor(True) tensor(0.0378) tensor(0.0378)
# tensor(True) tensor(0.2089) tensor(0.2089)
# tensor(True) tensor(0.0130) tensor(0.0130)
# tensor(True) tensor(0.2513) tensor(0.2513)
# tensor(True) tensor(0.2663) tensor(0.2663)
# tensor(True) tensor(0.0165) tensor(0.0165)
# tensor(True) tensor(0.3204) tensor(0.3204)
# tensor(True) tensor(0.0013) tensor(0.0013)
# tensor(True) tensor(8.1942e-05) tensor(8.1942e-05)
# tensor(True) tensor(0.0016) tensor(0.0016)
# tensor(True) tensor(0.1370) tensor(0.1370)
# tensor(True) tensor(0.0085) tensor(0.0085)
# tensor(True) tensor(0.1648) tensor(0.1648)
# tensor(True) tensor(0.0433) tensor(0.0433)
# tensor(True) tensor(0.0027) tensor(0.0027)
# tensor(True) tensor(0.0520) tensor(0.0520)
# tensor(True) tensor(0.0083) tensor(0.0083)
# tensor(True) tensor(0.0005) tensor(0.0005)
# tensor(True) tensor(0.0100) tensor(0.0100)
# tensor(True) tensor(0.1375) tensor(0.1375)
# tensor(True) tensor(0.0085) tensor(0.0085)
# tensor(True) tensor(0.1654) tensor(0.1654)
# tensor(True) tensor(0.0243) tensor(0.0243)
# tensor(True) tensor(0.0015) tensor(0.0015)
# tensor(True) tensor(0.0292) tensor(0.0292)
# tensor(True) tensor(0.0602) tensor(0.0602)
# tensor(True) tensor(0.0037) tensor(0.0037)
# tensor(True) tensor(0.0725) tensor(0.0725)
# tensor(True) tensor(0.1731) tensor(0.1731)
# tensor(True) tensor(0.0107) tensor(0.0107)
# tensor(True) tensor(0.2083) tensor(0.2083)
# tensor(True) tensor(0.2522) tensor(0.2522)
# tensor(True) tensor(0.0157) tensor(0.0157)
# tensor(True) tensor(0.3034) tensor(0.3034)
# tensor(True) tensor(0.3052) tensor(0.3052)
# tensor(True) tensor(0.0189) tensor(0.0189)
# tensor(True) tensor(0.3672) tensor(0.3672)
# tensor(True) tensor(0.0935) tensor(0.0935)
# tensor(True) tensor(0.0058) tensor(0.0058)
# tensor(True) tensor(0.1125) tensor(0.1125)
# tensor(True) tensor(0.0920) tensor(0.0920)
# tensor(True) tensor(0.0057) tensor(0.0057)
# tensor(True) tensor(0.1107) tensor(0.1107)
# tensor(True) tensor(0.2623) tensor(0.2623)
# tensor(True) tensor(0.0163) tensor(0.0163)
# tensor(True) tensor(0.3156) tensor(0.3156)
# tensor(True) tensor(0.0343) tensor(0.0343)
# tensor(True) tensor(0.0021) tensor(0.0021)
# tensor(True) tensor(0.0413) tensor(0.0413)
# tensor(True) tensor(0.1152) tensor(0.1152)
# tensor(True) tensor(0.0071) tensor(0.0071)
# tensor(True) tensor(0.1385) tensor(0.1385)
# tensor(True) tensor(0.0566) tensor(0.0566)
# tensor(True) tensor(0.0035) tensor(0.0035)
# tensor(True) tensor(0.0681) tensor(0.0681)
# tensor(True) tensor(0.1000) tensor(0.1000)
# tensor(True) tensor(0.0062) tensor(0.0062)
# tensor(True) tensor(0.1203) tensor(0.1203)
# tensor(True) tensor(0.1158) tensor(0.1158)
# tensor(True) tensor(0.0072) tensor(0.0072)
# tensor(True) tensor(0.1393) tensor(0.1393)
# tensor(True) tensor(0.0781) tensor(0.0781)
# tensor(True) tensor(0.0048) tensor(0.0048)
# tensor(True) tensor(0.0940) tensor(0.0940)
# tensor(True) tensor(0.0688) tensor(0.0688)
# tensor(True) tensor(0.0043) tensor(0.0043)
# tensor(True) tensor(0.0828) tensor(0.0828)
# tensor(True) tensor(0.0164) tensor(0.0164)
# tensor(True) tensor(0.1004) tensor(0.1004)
# tensor(True) tensor(-0.0188) tensor(-0.0188)
# tensor(True) tensor(0.0476) tensor(0.0476)
# tensor(True) tensor(0.0215) tensor(0.0215)
# tensor(True) tensor(-0.0407) tensor(-0.0407)
# tensor(True) tensor(0.0034) tensor(0.0034)
# tensor(True) tensor(-0.0354) tensor(-0.0354)
# tensor(True) tensor(-0.0010) tensor(-0.0010)
# tensor(True) tensor(0.0596) tensor(0.0596)
# tensor(True) tensor(0.0259) tensor(0.0259)
# tensor(True) tensor(-0.0509) tensor(-0.0509)
# tensor(True) tensor(0.0272) tensor(0.0272)
# tensor(True) tensor(-0.0709) tensor(-0.0709)
# tensor(True) tensor(-0.0190) tensor(-0.0190)
# tensor(True) tensor(0.1423) tensor(0.1423)
# tensor(True) tensor(-0.0196) tensor(-0.0196)
# tensor(True) tensor(-0.1173) tensor(-0.1173)
# tensor(True) tensor(0.0385) tensor(0.0385)
# tensor(True) tensor(-0.0208) tensor(-0.0208)
# tensor(True) tensor(-0.0310) tensor(-0.0310)
# tensor(True) tensor(0.0575) tensor(0.0575)
# tensor(True) tensor(0.0042) tensor(0.0042)
# tensor(True) tensor(-0.0480) tensor(-0.0480)
# tensor(True) tensor(0.0151) tensor(0.0151)
# tensor(True) tensor(-0.0071) tensor(-0.0071)
# tensor(True) tensor(-0.0122) tensor(-0.0122)
# tensor(True) tensor(0.1818) tensor(0.1818)
# tensor(True) tensor(-0.3024) tensor(-0.3024)
# tensor(True) tensor(-0.1355) tensor(-0.1355)
# tensor(True) tensor(0.1877) tensor(0.1877)
# tensor(True) tensor(0.0653) tensor(0.0653)
# tensor(True) tensor(-0.1594) tensor(-0.1594)
# tensor(True) tensor(0.0317) tensor(0.0317)
# tensor(True) tensor(0.0194) tensor(0.0194)
# tensor(True) tensor(-0.0273) tensor(-0.0273)
# tensor(True) tensor(0.0260) tensor(0.0260)
# tensor(True) tensor(0.0224) tensor(0.0224)
# tensor(True) tensor(-0.0228) tensor(-0.0228)
# tensor(True) tensor(0.0172) tensor(0.0172)
# tensor(True) tensor(-0.0019) tensor(-0.0019)
# tensor(True) tensor(-0.0142) tensor(-0.0142)
# tensor(True) tensor(0.0060) tensor(0.0060)
# tensor(True) tensor(-0.2088) tensor(-0.2088)
# tensor(True) tensor(0.0058) tensor(0.0058)
# tensor(True) tensor(0.0068) tensor(0.0068)
# tensor(True) tensor(-0.0839) tensor(-0.0839)
# tensor(True) tensor(-0.0013) tensor(-0.0013)
# tensor(True) tensor(0.2289) tensor(0.2289)
# tensor(True) tensor(-0.0161) tensor(-0.0161)
# tensor(True) tensor(-0.1894) tensor(-0.1894)
# tensor(True) tensor(0.0886) tensor(0.0886)
# tensor(True) tensor(-0.0068) tensor(-0.0068)
# tensor(True) tensor(-0.0733) tensor(-0.0733)
# tensor(True) tensor(0.1789) tensor(0.1789)
# tensor(True) tensor(0.0405) tensor(0.0405)
# tensor(True) tensor(-0.1508) tensor(-0.1508)
# tensor(True) tensor(0.1092) tensor(0.1092)
# tensor(True) tensor(-0.0411) tensor(-0.0411)
# tensor(True) tensor(-0.0886) tensor(-0.0886)
# tensor(True) tensor(0.0239) tensor(0.0239)
# tensor(True) tensor(0.0009) tensor(0.0009)
# tensor(True) tensor(-0.0199) tensor(-0.0199)
# tensor(True) tensor(0.0111) tensor(0.0111)
# tensor(True) tensor(0.0253) tensor(0.0253)
# tensor(True) tensor(-0.0105) tensor(-0.0105)
# tensor(True) tensor(0.0372) tensor(0.0372)
# tensor(True) tensor(-0.0402) tensor(-0.0402)
# tensor(True) tensor(-0.0289) tensor(-0.0289)
# tensor(True) tensor(0.2254) tensor(0.2254)
# tensor(True) tensor(-0.0815) tensor(-0.0815)
# tensor(True) tensor(-0.1832) tensor(-0.1832)
# tensor(True) tensor(0.0017) tensor(0.0017)
# tensor(True) tensor(-0.0938) tensor(-0.0938)
# tensor(True) tensor(0.0034) tensor(0.0034)
# tensor(True) tensor(0.0980) tensor(0.0980)
# tensor(True) tensor(0.1200) tensor(0.1200)
# tensor(True) tensor(-0.0877) tensor(-0.0877)
# tensor(True) tensor(0.0838) tensor(0.0838)
# tensor(True) tensor(-0.0788) tensor(-0.0788)
# tensor(True) tensor(-0.0656) tensor(-0.0656)
# tensor(True) tensor(-0.0042) tensor(-0.0042)
# tensor(True) tensor(-0.0285) tensor(-0.0285)
# tensor(True) tensor(0.0050) tensor(0.0050)
# tensor(True) tensor(0.1317) tensor(0.1317)
# tensor(True) tensor(-0.2191) tensor(-0.2191)
# tensor(True) tensor(-0.0982) tensor(-0.0982)
# tensor(True) tensor(0.0230) tensor(0.0230)
# tensor(True) tensor(-0.0282) tensor(-0.0282)
# tensor(True) tensor(-0.0177) tensor(-0.0177)
# tensor(True) tensor(0.0375) tensor(0.0375)
# tensor(True) tensor(0.0425) tensor(0.0425)
# tensor(True) tensor(-0.0334) tensor(-0.0334)
# tensor(True) tensor(0.0114) tensor(0.0114)
# tensor(True) tensor(0.0047) tensor(0.0047)
# tensor(True) tensor(-0.0097) tensor(-0.0097)
# tensor(True) tensor(-0.0450) tensor(-0.0450)
# tensor(True) tensor(0.0894) tensor(0.0894)
# tensor(True) tensor(0.0222) tensor(0.0222)
# tensor(True) tensor(-0.0267) tensor(-0.0267)
# tensor(True) tensor(0.1053) tensor(0.1053)
# tensor(True) tensor(0.0519) tensor(0.0519)
# tensor(True) tensor(-0.0595) tensor(-0.0595)
# tensor(True) tensor(0.0375) tensor(0.0375)
# tensor(True) tensor(-0.0337) tensor(-0.0337)
# tensor(True) tensor(-0.0436) tensor(-0.0436)
# tensor(True) tensor(0.1819) tensor(0.1819)
# tensor(True) tensor(-0.0274) tensor(-0.0274)
# tensor(True) tensor(-0.0184) tensor(-0.0184)
# tensor(True) tensor(0.2094) tensor(0.2094)
# tensor(True) tensor(0.2347) tensor(0.2347)
# tensor(True) tensor(-0.0076) tensor(-0.0076)
# tensor(True) tensor(0.0145) tensor(0.0145)
# tensor(True) tensor(0.0158) tensor(0.0158)
# tensor(True) tensor(-0.0112) tensor(-0.0112)
# tensor(True) tensor(0.0293) tensor(0.0293)
# tensor(True) tensor(0.1188) tensor(0.1188)
# tensor(True) tensor(-0.2116) tensor(-0.2116)
# tensor(True) tensor(0.1769) tensor(0.1769)
# tensor(True) tensor(0.1593) tensor(0.1593)
# tensor(True) tensor(-0.0790) tensor(-0.0790)
# tensor(True) tensor(0.2120) tensor(0.2120)
# tensor(True) tensor(0.0416) tensor(0.0416)
# tensor(True) tensor(-0.0857) tensor(-0.0857)
# tensor(True) tensor(0.1092) tensor(0.1092)
# tensor(True) tensor(0.2126) tensor(0.2126)
# tensor(True) tensor(-0.0003) tensor(-0.0003)
# tensor(True) tensor(0.0285) tensor(0.0285)
# tensor(True) tensor(0.0251) tensor(0.0251)
# tensor(True) tensor(0.0118) tensor(0.0118)
# tensor(True) tensor(0.0692) tensor(0.0692)
# tensor(True) tensor(0.0922) tensor(0.0922)
# tensor(True) tensor(0.0153) tensor(0.0153)
# tensor(True) tensor(0.0496) tensor(0.0496)
# tensor(True) tensor(0.0848) tensor(0.0848)
# tensor(True) tensor(-0.0092) tensor(-0.0092)
# tensor(True) tensor(0.1997) tensor(0.1997)
# tensor(True) tensor(0.1846) tensor(0.1846)
# tensor(True) tensor(0.0212) tensor(0.0212)
# tensor(True) tensor(0.1700) tensor(0.1700)
# tensor(True) tensor(0.0512) tensor(0.0512)
# tensor(True) tensor(0.0076) tensor(0.0076)
# tensor(True) tensor(0.0842) tensor(0.0842)
# tensor(True) tensor(0.0190) tensor(0.0190)
# tensor(True) tensor(-0.0381) tensor(-0.0381)
# tensor(True) tensor(0.0925) tensor(0.0925)
# tensor(True) tensor(0.1237) tensor(0.1237)
# tensor(True) tensor(-0.0173) tensor(-0.0173)
# tensor(True) tensor(0.1435) tensor(0.1435)
# tensor(True) tensor(0.0418) tensor(0.0418)
# tensor(True) tensor(-0.0083) tensor(-0.0083)
# tensor(True) tensor(0.0115) tensor(0.0115)
# tensor(True) tensor(0.0295) tensor(0.0295)
# tensor(True) tensor(0.0439) tensor(0.0439)
# tensor(True) tensor(0.1335) tensor(0.1335)
# tensor(True) tensor(0.0441) tensor(0.0441)
# tensor(True) tensor(-0.1406) tensor(-0.1406)
# tensor(True) tensor(0.4145) tensor(0.4145)
# tensor(True) tensor(-0.0579) tensor(-0.0579)
# tensor(True) tensor(-0.1495) tensor(-0.1495)
# tensor(True) tensor(0.2405) tensor(0.2405)
# tensor(True) tensor(0.0571) tensor(0.0571)
# tensor(True) tensor(-0.0092) tensor(-0.0092)
# tensor(True) tensor(0.0313) tensor(0.0313)
# tensor(True) tensor(0.0276) tensor(0.0276)
# tensor(True) tensor(0.0825) tensor(0.0825)
# tensor(True) tensor(0.0899) tensor(0.0899)
# tensor(True) tensor(0.1059) tensor(0.1059)
# tensor(True) tensor(-0.0042) tensor(-0.0042)
# tensor(True) tensor(0.0020) tensor(0.0020)
# tensor(True) tensor(0.0078) tensor(0.0078)
# tensor(True) tensor(0.0723) tensor(0.0723)
# tensor(True) tensor(0.3410) tensor(0.3410)
# tensor(True) tensor(0.1887) tensor(0.1887)
# tensor(True) tensor(-0.0799) tensor(-0.0799)
# tensor(True) tensor(0.2275) tensor(0.2275)
# tensor(True) tensor(0.1107) tensor(0.1107)
# tensor(True) tensor(-0.0576) tensor(-0.0576)
# tensor(True) tensor(0.0889) tensor(0.0889)
# tensor(True) tensor(0.3132) tensor(0.3132)
# tensor(True) tensor(0.1587) tensor(0.1587)
# tensor(True) tensor(0.4071) tensor(0.4071)
# tensor(True) tensor(0.1495) tensor(0.1495)
# tensor(True) tensor(-0.0609) tensor(-0.0609)
# tensor(True) tensor(0.1260) tensor(0.1260)
# tensor(True) tensor(-0.0163) tensor(-0.0163)
# tensor(True) tensor(-0.0355) tensor(-0.0355)
# tensor(True) tensor(0.0622) tensor(0.0622)
# tensor(True) tensor(-0.0039) tensor(-0.0039)
# tensor(True) tensor(0.1746) tensor(0.1746)
# tensor(True) tensor(0.2006) tensor(0.2006)
# tensor(True) tensor(0.1683) tensor(0.1683)
# tensor(True) tensor(0.1233) tensor(0.1233)
# tensor(True) tensor(0.1146) tensor(0.1146)
# tensor(True) tensor(0.1542) tensor(0.1542)
# tensor(True) tensor(0.0096) tensor(0.0096)
# tensor(True) tensor(0.0095) tensor(0.0095)
# tensor(True) tensor(5.0059e-05) tensor(5.0059e-05)
# tensor(True) tensor(0.0525) tensor(0.0525)
# tensor(True) tensor(0.0004) tensor(0.0004)
# tensor(True) tensor(0.0479) tensor(0.0479)
# tensor(True) tensor(0.1676) tensor(0.1676)
# tensor(True) tensor(0.0065) tensor(0.0065)
# tensor(True) tensor(0.0659) tensor(0.0659)
# tensor(True) tensor(0.0075) tensor(0.0075)
# tensor(True) tensor(0.0075) tensor(0.0075)
# tensor(True) tensor(0.0005) tensor(0.0005)
# tensor(True) tensor(0.0850) tensor(0.0850)
# tensor(True) tensor(0.0245) tensor(0.0245)
# tensor(True) tensor(0.0024) tensor(0.0024)
# tensor(True) tensor(0.0474) tensor(0.0474)
# tensor(True) tensor(0.1567) tensor(0.1567)
# tensor(True) tensor(0.2268) tensor(0.2268)
# tensor(True) tensor(0.0554) tensor(0.0554)
# tensor(True) tensor(0.0424) tensor(0.0424)
# tensor(True) tensor(0.1374) tensor(0.1374)
# tensor(True) tensor(0.0310) tensor(0.0310)
# tensor(True) tensor(0.0023) tensor(0.0023)
# tensor(True) tensor(5.9437e-05) tensor(5.9437e-05)
# tensor(True) tensor(0.2714) tensor(0.2714)
# tensor(True) tensor(0.1746) tensor(0.1746)
# tensor(True) tensor(0.1979) tensor(0.1979)
# tensor(True) tensor(0.0557) tensor(0.0557)
# tensor(True) tensor(0.0390) tensor(0.0390)
# tensor(True) tensor(0.0465) tensor(0.0465)
# tensor(True) tensor(0.0027) tensor(0.0027)
# tensor(True) tensor(0.0986) tensor(0.0986)
# tensor(True) tensor(0.0459) tensor(0.0459)
# tensor(True) tensor(0.0338) tensor(0.0338)
# tensor(True) tensor(0.0441) tensor(0.0441)
# tensor(True) tensor(0.0519) tensor(0.0519)
# tensor(True) tensor(0.0382) tensor(0.0382)
# tensor(True) tensor(0.0733) tensor(0.0733)
# tensor(True) tensor(0.0046) tensor(0.0046)
# tensor(True) tensor(0.0073) tensor(0.0073)
# tensor(True) tensor(0.0008) tensor(0.0008)
# tensor(True) tensor(0.0455) tensor(0.0455)
# tensor(True) tensor(0.0430) tensor(0.0430)
# tensor(True) tensor(0.1086) tensor(0.1086)
# tensor(True) tensor(0.0543) tensor(0.0543)
# tensor(True) tensor(0.0730) tensor(0.0730)
# tensor(True) tensor(0.1993) tensor(0.1993)
# tensor(True) tensor(0.1748) tensor(0.1748)
# tensor(True) tensor(0.0099) tensor(0.0099)
# tensor(True) tensor(0.0490) tensor(0.0490)
# tensor(True) tensor(0.0052) tensor(0.0052)
# tensor(True) tensor(0.0141) tensor(0.0141)
# tensor(True) tensor(0.1096) tensor(0.1096)
# tensor(True) tensor(0.2184) tensor(0.2184)
# tensor(True) tensor(0.0533) tensor(0.0533)
# tensor(True) tensor(0.0220) tensor(0.0220)
# tensor(True) tensor(0.0591) tensor(0.0591)
# tensor(True) tensor(0.0945) tensor(0.0945)
# tensor(True) tensor(0.1494) tensor(0.1494)
# tensor(True) tensor(0.0418) tensor(0.0418)
# tensor(True) tensor(0.1913) tensor(0.1913)
# tensor(True) tensor(0.1478) tensor(0.1478)
# tensor(True) tensor(0.0202) tensor(0.0202)
# tensor(True) tensor(0.1678) tensor(0.1678)
# tensor(True) tensor(0.1075) tensor(0.1075)
# tensor(True) tensor(0.1692) tensor(0.1692)
# tensor(True) tensor(0.0051) tensor(0.0051)
# tensor(True) tensor(0.0159) tensor(0.0159)
# tensor(True) tensor(0.0079) tensor(0.0079)
# tensor(True) tensor(0.0064) tensor(0.0064)
# tensor(True) tensor(0.0339) tensor(0.0339)
# tensor(True) tensor(0.0795) tensor(0.0795)
# tensor(True) tensor(0.0013) tensor(0.0013)
# tensor(True) tensor(0.0665) tensor(0.0665)
# tensor(True) tensor(0.0709) tensor(0.0709)
# tensor(True) tensor(0.0095) tensor(0.0095)
# tensor(True) tensor(0.0054) tensor(0.0054)
# tensor(True) tensor(0.0095) tensor(0.0095)
# tensor(True) tensor(0.0934) tensor(0.0934)
# tensor(True) tensor(0.1843) tensor(0.1843)
# tensor(True) tensor(0.0196) tensor(0.0196)
# tensor(True) tensor(0.0346) tensor(0.0346)
# tensor(True) tensor(0.0638) tensor(0.0638)
# tensor(True) tensor(0.0704) tensor(0.0704)
# tensor(True) tensor(0.0545) tensor(0.0545)
# tensor(True) tensor(0.2202) tensor(0.2202)
# tensor(True) tensor(0.0909) tensor(0.0909)
# tensor(True) tensor(0.1392) tensor(0.1392)
# tensor(True) tensor(0.1016) tensor(0.1016)
# tensor(True) tensor(0.1564) tensor(0.1564)
# tensor(True) tensor(0.2054) tensor(0.2054)
# tensor(True) tensor(0.0845) tensor(0.0845)
# tensor(True) tensor(0.0918) tensor(0.0918)
# tensor(True) tensor(0.0365) tensor(0.0365)
# tensor(True) tensor(0.0785) tensor(0.0785)
# tensor(True) tensor(0.0390) tensor(0.0390)
# tensor(True) tensor(0.0011) tensor(0.0011)
# tensor(True) tensor(0.0335) tensor(0.0335)
# tensor(True) tensor(0.0161) tensor(0.0161)
# tensor(True) tensor(-0.0159) tensor(-0.0159)
# tensor(True) tensor(0.0725) tensor(0.0725)
# tensor(True) tensor(0.0516) tensor(0.0516)
# tensor(True) tensor(-0.0362) tensor(-0.0362)
# tensor(True) tensor(0.0655) tensor(0.0655)
# tensor(True) tensor(0.0464) tensor(0.0464)
# tensor(True) tensor(0.0004) tensor(0.0004)
# tensor(True) tensor(0.0060) tensor(0.0060)
# tensor(True) tensor(0.0029) tensor(0.0029)
# tensor(True) tensor(-0.0929) tensor(-0.0929)
# tensor(True) tensor(0.1865) tensor(0.1865)
# tensor(True) tensor(0.1167) tensor(0.1167)
# tensor(True) tensor(0.1565) tensor(0.1565)
# tensor(True) tensor(0.1199) tensor(0.1199)
# tensor(True) tensor(0.0434) tensor(0.0434)
# tensor(True) tensor(0.0489) tensor(0.0489)
# tensor(True) tensor(0.0595) tensor(0.0595)
# tensor(True) tensor(0.0312) tensor(0.0312)
# tensor(True) tensor(-0.0678) tensor(-0.0678)
# tensor(True) tensor(0.0841) tensor(0.0841)
# tensor(True) tensor(0.0591) tensor(0.0591)
# tensor(True) tensor(0.0447) tensor(0.0447)
# tensor(True) tensor(0.2978) tensor(0.2978)
# tensor(True) tensor(0.1608) tensor(0.1608)
# tensor(True) tensor(0.0904) tensor(0.0904)
# tensor(True) tensor(0.4050) tensor(0.4050)
# tensor(True) tensor(0.2146) tensor(0.2146)
# tensor(True) tensor(0.1026) tensor(0.1026)
# tensor(True) tensor(0.0736) tensor(0.0736)
# tensor(True) tensor(0.0163) tensor(0.0163)
# tensor(True) tensor(0.1498) tensor(0.1498)
# tensor(True) tensor(0.2329) tensor(0.2329)
# tensor(True) tensor(0.1058) tensor(0.1058)
# tensor(True) tensor(0.0490) tensor(0.0490)
# tensor(True) tensor(0.1204) tensor(0.1204)
# tensor(True) tensor(0.0471) tensor(0.0471)
# tensor(True) tensor(0.0547) tensor(0.0547)
# tensor(True) tensor(0.0295) tensor(0.0295)
# tensor(True) tensor(0.0186) tensor(0.0186)
# tensor(True) tensor(0.0232) tensor(0.0232)
# tensor(True) tensor(0.0305) tensor(0.0305)
# tensor(True) tensor(0.0112) tensor(0.0112)
# tensor(True) tensor(0.2146) tensor(0.2146)
# tensor(True) tensor(0.2214) tensor(0.2214)
# tensor(True) tensor(0.0812) tensor(0.0812)
# tensor(True) tensor(0.0460) tensor(0.0460)
# tensor(True) tensor(0.0551) tensor(0.0551)
# tensor(True) tensor(0.0159) tensor(0.0159)
# tensor(True) tensor(0.0201) tensor(0.0201)
# tensor(True) tensor(0.0109) tensor(0.0109)
# tensor(True) tensor(0.0035) tensor(0.0035)
# tensor(True) tensor(0.0102) tensor(0.0102)
# tensor(True) tensor(0.0519) tensor(0.0519)
# tensor(True) tensor(0.0305) tensor(0.0305)
# tensor(True) tensor(0.1124) tensor(0.1124)
# tensor(True) tensor(0.2774) tensor(0.2774)
# tensor(True) tensor(0.1164) tensor(0.1164)
# tensor(True) tensor(-0.0066) tensor(-0.0066)
# tensor(True) tensor(0.1364) tensor(0.1364)
# tensor(True) tensor(0.0702) tensor(0.0702)
# tensor(True) tensor(0.0722) tensor(0.0722)
# tensor(True) tensor(0.2711) tensor(0.2711)
# tensor(True) tensor(0.1467) tensor(0.1467)
# tensor(True) tensor(0.0299) tensor(0.0299)
# tensor(True) tensor(0.0347) tensor(0.0347)
# tensor(True) tensor(0.0120) tensor(0.0120)
# tensor(True) tensor(0.0384) tensor(0.0384)
# tensor(True) tensor(0.0209) tensor(0.0209)
# tensor(True) tensor(0.0073) tensor(0.0073)
# tensor(True) tensor(0.3365) tensor(0.3365)
# tensor(True) tensor(0.1956) tensor(0.1956)
# tensor(True) tensor(0.0484) tensor(0.0484)
# tensor(True) tensor(0.0322) tensor(0.0322)
# tensor(True) tensor(0.1409) tensor(0.1409)
# tensor(True) tensor(0.0781) tensor(0.0781)
# tensor(True) tensor(0.0472) tensor(0.0472)
# tensor(True) tensor(0.1066) tensor(0.1066)
# tensor(True) tensor(0.0414) tensor(0.0414)
# tensor(True) tensor(0.0433) tensor(0.0433)
# tensor(True) tensor(0.0515) tensor(0.0515)
# tensor(True) tensor(0.0212) tensor(0.0212)
# tensor(True) tensor(0.1677) tensor(0.1677)
# tensor(True) tensor(0.1808) tensor(0.1808)
# tensor(True) tensor(0.0573) tensor(0.0573)
# tensor(True) tensor(0.0791) tensor(0.0791)
# tensor(True) tensor(0.2264) tensor(0.2264)
# tensor(True) tensor(0.1190) tensor(0.1190)
# tensor(True) tensor(-0.0273) tensor(-0.0273)
# tensor(True) tensor(0.2016) tensor(0.2016)
# tensor(True) tensor(0.1189) tensor(0.1189)
# tensor(True) tensor(0.0004) tensor(0.0004)
# tensor(True) tensor(0.0540) tensor(0.0540)
# tensor(True) tensor(-0.0514) tensor(-0.0514)
# tensor(True) tensor(-0.0087) tensor(-0.0087)
# tensor(True) tensor(0.0320) tensor(0.0320)
# tensor(True) tensor(-0.1557) tensor(-0.1557)
# tensor(True) tensor(-0.0087) tensor(-0.0087)
# tensor(True) tensor(0.0771) tensor(0.0771)
# tensor(True) tensor(-0.0399) tensor(-0.0399)
# tensor(True) tensor(-0.0381) tensor(-0.0381)
# tensor(True) tensor(0.0521) tensor(0.0521)
# tensor(True) tensor(-0.1060) tensor(-0.1060)
# tensor(True) tensor(-0.0026) tensor(-0.0026)
# tensor(True) tensor(0.0045) tensor(0.0045)
# tensor(True) tensor(-0.0085) tensor(-0.0085)
# tensor(True) tensor(-0.0120) tensor(-0.0120)
# tensor(True) tensor(0.0028) tensor(0.0028)
# tensor(True) tensor(-0.0312) tensor(-0.0312)
# tensor(True) tensor(-0.0463) tensor(-0.0463)
# tensor(True) tensor(0.1742) tensor(0.1742)
# tensor(True) tensor(-0.1785) tensor(-0.1785)
# tensor(True) tensor(-0.0035) tensor(-0.0035)
# tensor(True) tensor(0.0101) tensor(0.0101)
# tensor(True) tensor(-0.0186) tensor(-0.0186)
# tensor(True) tensor(-0.0254) tensor(-0.0254)
# tensor(True) tensor(0.0136) tensor(0.0136)
# tensor(True) tensor(0.0060) tensor(0.0060)
# tensor(True) tensor(-0.0354) tensor(-0.0354)
# tensor(True) tensor(0.0158) tensor(0.0158)
# tensor(True) tensor(-0.1520) tensor(-0.1520)
# tensor(True) tensor(0.0016) tensor(0.0016)
# tensor(True) tensor(0.0295) tensor(0.0295)
# tensor(True) tensor(-0.0507) tensor(-0.0507)
# tensor(True) tensor(-0.0420) tensor(-0.0420)
# tensor(True) tensor(0.0696) tensor(0.0696)
# tensor(True) tensor(-0.0775) tensor(-0.0775)
# tensor(True) tensor(-0.0149) tensor(-0.0149)
# tensor(True) tensor(0.0168) tensor(0.0168)
# tensor(True) tensor(-0.0351) tensor(-0.0351)
# tensor(True) tensor(-0.0128) tensor(-0.0128)
# tensor(True) tensor(0.0107) tensor(0.0107)
# tensor(True) tensor(-0.0212) tensor(-0.0212)
# tensor(True) tensor(-0.0792) tensor(-0.0792)
# tensor(True) tensor(0.0125) tensor(0.0125)
# tensor(True) tensor(-0.0605) tensor(-0.0605)
# tensor(True) tensor(0.0195) tensor(0.0195)
# tensor(True) tensor(0.0883) tensor(0.0883)
# tensor(True) tensor(-0.1029) tensor(-0.1029)
# tensor(True) tensor(-0.0037) tensor(-0.0037)
# tensor(True) tensor(0.0069) tensor(0.0069)
# tensor(True) tensor(-0.0109) tensor(-0.0109)
# tensor(True) tensor(-0.0006) tensor(-0.0006)
# tensor(True) tensor(0.0218) tensor(0.0218)
# tensor(True) tensor(-0.0811) tensor(-0.0811)
# tensor(True) tensor(-0.0073) tensor(-0.0073)
# tensor(True) tensor(0.0188) tensor(0.0188)
# tensor(True) tensor(0.0347) tensor(0.0347)
# tensor(True) tensor(-0.0004) tensor(-0.0004)
# tensor(True) tensor(0.0003) tensor(0.0003)
# tensor(True) tensor(-8.7984e-05) tensor(-8.7984e-05)
# tensor(True) tensor(-0.0003) tensor(-0.0003)
# tensor(True) tensor(0.0008) tensor(0.0008)
# tensor(True) tensor(-0.0011) tensor(-0.0011)
# tensor(True) tensor(-0.1067) tensor(-0.1067)
# tensor(True) tensor(-0.0014) tensor(-0.0014)
# tensor(True) tensor(0.0183) tensor(0.0183)
# tensor(True) tensor(-0.0405) tensor(-0.0405)
# tensor(True) tensor(0.0324) tensor(0.0324)
# tensor(True) tensor(-0.0286) tensor(-0.0286)
# tensor(True) tensor(-0.0407) tensor(-0.0407)
# tensor(True) tensor(0.0181) tensor(0.0181)
# tensor(True) tensor(0.0378) tensor(0.0378)
# tensor(True) tensor(-0.1367) tensor(-0.1367)
# tensor(True) tensor(0.0181) tensor(0.0181)
# tensor(True) tensor(-0.0649) tensor(-0.0649)
# tensor(True) tensor(-0.0013) tensor(-0.0013)
# tensor(True) tensor(0.1127) tensor(0.1127)
# tensor(True) tensor(-0.0445) tensor(-0.0445)
# tensor(True) tensor(-0.0806) tensor(-0.0806)
# tensor(True) tensor(0.1320) tensor(0.1320)
# tensor(True) tensor(-0.1389) tensor(-0.1389)
# tensor(True) tensor(-0.0708) tensor(-0.0708)
# tensor(True) tensor(0.0494) tensor(0.0494)
# tensor(True) tensor(-0.0332) tensor(-0.0332)
# tensor(True) tensor(-0.0026) tensor(-0.0026)
# tensor(True) tensor(0.0101) tensor(0.0101)
# tensor(True) tensor(0.0031) tensor(0.0031)
# tensor(True) tensor(-0.0114) tensor(-0.0114)
# tensor(True) tensor(0.0075) tensor(0.0075)
# tensor(True) tensor(0.0007) tensor(0.0007)
# tensor(True) tensor(-0.0397) tensor(-0.0397)
# tensor(True) tensor(0.0658) tensor(0.0658)
# tensor(True) tensor(-0.1572) tensor(-0.1572)
# tensor(True) tensor(-0.0636) tensor(-0.0636)
# tensor(True) tensor(0.1624) tensor(0.1624)
# tensor(True) tensor(-0.1468) tensor(-0.1468)
# tensor(True) tensor(0.0004) tensor(0.0004)
# tensor(True) tensor(2.4814e-05) tensor(2.4814e-05)
# tensor(True) tensor(0.0005) tensor(0.0005)
# tensor(True) tensor(0.0084) tensor(0.0084)
# tensor(True) tensor(0.0005) tensor(0.0005)
# tensor(True) tensor(0.0101) tensor(0.0101)
# tensor(True) tensor(0.0767) tensor(0.0767)
# tensor(True) tensor(0.0048) tensor(0.0048)
# tensor(True) tensor(0.0923) tensor(0.0923)
# tensor(True) tensor(0.1144) tensor(0.1144)
# tensor(True) tensor(0.0071) tensor(0.0071)
# tensor(True) tensor(0.1377) tensor(0.1377)
# tensor(True) tensor(0.3046) tensor(0.3046)
# tensor(True) tensor(0.0189) tensor(0.0189)
# tensor(True) tensor(0.3664) tensor(0.3664)
# tensor(True) tensor(0.0053) tensor(0.0053)
# tensor(True) tensor(0.0003) tensor(0.0003)
# tensor(True) tensor(0.0064) tensor(0.0064)
# tensor(True) tensor(0.0207) tensor(0.0207)
# tensor(True) tensor(0.0013) tensor(0.0013)
# tensor(True) tensor(0.0249) tensor(0.0249)
# tensor(True) tensor(0.1601) tensor(0.1601)
# tensor(True) tensor(0.0099) tensor(0.0099)
# tensor(True) tensor(0.1926) tensor(0.1926)
# tensor(True) tensor(0.0386) tensor(0.0386)
# tensor(True) tensor(0.0024) tensor(0.0024)
# tensor(True) tensor(0.0464) tensor(0.0464)
# tensor(True) tensor(0.2957) tensor(0.2957)
# tensor(True) tensor(0.0183) tensor(0.0183)
# tensor(True) tensor(0.3557) tensor(0.3557)
# tensor(True) tensor(0.1544) tensor(0.1544)
# tensor(True) tensor(0.0096) tensor(0.0096)
# tensor(True) tensor(0.1858) tensor(0.1858)
# tensor(True) tensor(0.0797) tensor(0.0797)
# tensor(True) tensor(0.0049) tensor(0.0049)
# tensor(True) tensor(0.0959) tensor(0.0959)
# tensor(True) tensor(0.0319) tensor(0.0319)
# tensor(True) tensor(0.0020) tensor(0.0020)
# tensor(True) tensor(0.0383) tensor(0.0383)
# tensor(True) tensor(0.0701) tensor(0.0701)
# tensor(True) tensor(0.0043) tensor(0.0043)
# tensor(True) tensor(0.0843) tensor(0.0843)
# tensor(True) tensor(0.0585) tensor(0.0585)
# tensor(True) tensor(0.0036) tensor(0.0036)
# tensor(True) tensor(0.0704) tensor(0.0704)
# tensor(True) tensor(0.0687) tensor(0.0687)
# tensor(True) tensor(0.0043) tensor(0.0043)
# tensor(True) tensor(0.0826) tensor(0.0826)
# tensor(True) tensor(0.2230) tensor(0.2230)
# tensor(True) tensor(0.0138) tensor(0.0138)
# tensor(True) tensor(0.2682) tensor(0.2682)
# tensor(True) tensor(0.0541) tensor(0.0541)
# tensor(True) tensor(0.0034) tensor(0.0034)
# tensor(True) tensor(0.0651) tensor(0.0651)
# tensor(True) tensor(0.0765) tensor(0.0765)
# tensor(True) tensor(0.0048) tensor(0.0048)
# tensor(True) tensor(0.0921) tensor(0.0921)
# tensor(True) tensor(0.0845) tensor(0.0845)
# tensor(True) tensor(0.0052) tensor(0.0052)
# tensor(True) tensor(0.1017) tensor(0.1017)
# tensor(True) tensor(0.0428) tensor(0.0428)
# tensor(True) tensor(0.0027) tensor(0.0027)
# tensor(True) tensor(0.0515) tensor(0.0515)
# tensor(True) tensor(0.2417) tensor(0.2417)
# tensor(True) tensor(0.0150) tensor(0.0150)
# tensor(True) tensor(0.2907) tensor(0.2907)
# tensor(True) tensor(0.0106) tensor(0.0106)
# tensor(True) tensor(0.0007) tensor(0.0007)
# tensor(True) tensor(0.0127) tensor(0.0127)
# tensor(True) tensor(0.1026) tensor(0.1026)
# tensor(True) tensor(0.0064) tensor(0.0064)
# tensor(True) tensor(0.1235) tensor(0.1235)
# tensor(True) tensor(0.0146) tensor(0.0146)
# tensor(True) tensor(0.0009) tensor(0.0009)
# tensor(True) tensor(0.0175) tensor(0.0175)
# tensor(True) tensor(0.2873) tensor(0.2873)
# tensor(True) tensor(0.0178) tensor(0.0178)
# tensor(True) tensor(0.3457) tensor(0.3457)
# tensor(True) tensor(0.0168) tensor(0.0168)
# tensor(True) tensor(0.0010) tensor(0.0010)
# tensor(True) tensor(0.0202) tensor(0.0202)
# tensor(True) tensor(0.0176) tensor(0.0176)
# tensor(True) tensor(0.0011) tensor(0.0011)
# tensor(True) tensor(0.0212) tensor(0.0212)
# tensor(True) tensor(0.0055) tensor(0.0055)
# tensor(True) tensor(0.0003) tensor(0.0003)
# tensor(True) tensor(0.0067) tensor(0.0067)
# tensor(True) tensor(0.2493) tensor(0.2493)
# tensor(True) tensor(0.0155) tensor(0.0155)
# tensor(True) tensor(0.2999) tensor(0.2999)
# tensor(True) tensor(0.2164) tensor(0.2164)
# tensor(True) tensor(0.0134) tensor(0.0134)
# tensor(True) tensor(0.2604) tensor(0.2604)
# tensor(True) tensor(0.0360) tensor(0.0360)
# tensor(True) tensor(0.0022) tensor(0.0022)
# tensor(True) tensor(0.0433) tensor(0.0433)
# tensor(True) tensor(0.0333) tensor(0.0333)
# tensor(True) tensor(0.0212) tensor(0.0212)
# tensor(True) tensor(0.1421) tensor(0.1421)
# tensor(True) tensor(0.0008) tensor(0.0008)
# tensor(True) tensor(0.0011) tensor(0.0011)
# tensor(True) tensor(0.0015) tensor(0.0015)
# tensor(True) tensor(0.1221) tensor(0.1221)
# tensor(True) tensor(0.0112) tensor(0.0112)
# tensor(True) tensor(0.0177) tensor(0.0177)
# tensor(True) tensor(0.0905) tensor(0.0905)
# tensor(True) tensor(0.2641) tensor(0.2641)
# tensor(True) tensor(0.2407) tensor(0.2407)
# tensor(True) tensor(0.0941) tensor(0.0941)
# tensor(True) tensor(0.0286) tensor(0.0286)
# tensor(True) tensor(0.0283) tensor(0.0283)
# tensor(True) tensor(0.0168) tensor(0.0168)
# tensor(True) tensor(0.0888) tensor(0.0888)
# tensor(True) tensor(0.0055) tensor(0.0055)
# tensor(True) tensor(0.0526) tensor(0.0526)
# tensor(True) tensor(0.0367) tensor(0.0367)
# tensor(True) tensor(0.0407) tensor(0.0407)
# tensor(True) tensor(0.0178) tensor(0.0178)
# tensor(True) tensor(0.0386) tensor(0.0386)
# tensor(True) tensor(0.0247) tensor(0.0247)
# tensor(True) tensor(0.1991) tensor(0.1991)
# tensor(True) tensor(0.1029) tensor(0.1029)
# tensor(True) tensor(0.1867) tensor(0.1867)
# tensor(True) tensor(0.0657) tensor(0.0657)
# tensor(True) tensor(0.0365) tensor(0.0365)
# tensor(True) tensor(0.0067) tensor(0.0067)
# tensor(True) tensor(0.0104) tensor(0.0104)
# tensor(True) tensor(0.0222) tensor(0.0222)
# tensor(True) tensor(0.0213) tensor(0.0213)
# tensor(True) tensor(0.0140) tensor(0.0140)
# tensor(True) tensor(0.0477) tensor(0.0477)
# tensor(True) tensor(0.0502) tensor(0.0502)
# tensor(True) tensor(0.0481) tensor(0.0481)
# tensor(True) tensor(0.0143) tensor(0.0143)
# tensor(True) tensor(0.0690) tensor(0.0690)
# tensor(True) tensor(0.0569) tensor(0.0569)
# tensor(True) tensor(0.0210) tensor(0.0210)
# tensor(True) tensor(0.0661) tensor(0.0661)
# tensor(True) tensor(0.1655) tensor(0.1655)
# tensor(True) tensor(0.0056) tensor(0.0056)
# tensor(True) tensor(0.0303) tensor(0.0303)
# tensor(True) tensor(0.0619) tensor(0.0619)
# tensor(True) tensor(0.0047) tensor(0.0047)
# tensor(True) tensor(0.0175) tensor(0.0175)
# tensor(True) tensor(0.0086) tensor(0.0086)
# tensor(True) tensor(0.0881) tensor(0.0881)
# tensor(True) tensor(0.0029) tensor(0.0029)
# tensor(True) tensor(0.0504) tensor(0.0504)
# tensor(True) tensor(0.1077) tensor(0.1077)
# tensor(True) tensor(0.0510) tensor(0.0510)
# tensor(True) tensor(0.1188) tensor(0.1188)
# tensor(True) tensor(0.1562) tensor(0.1562)
# tensor(True) tensor(0.1829) tensor(0.1829)
# tensor(True) tensor(0.1690) tensor(0.1690)
# tensor(True) tensor(0.1731) tensor(0.1731)
# tensor(True) tensor(0.1279) tensor(0.1279)
# tensor(True) tensor(0.0053) tensor(0.0053)
# tensor(True) tensor(0.0367) tensor(0.0367)
# tensor(True) tensor(0.0081) tensor(0.0081)
# tensor(True) tensor(0.0157) tensor(0.0157)
# tensor(True) tensor(0.0023) tensor(0.0023)
# tensor(True) tensor(0.0221) tensor(0.0221)
# tensor(True) tensor(0.1510) tensor(0.1510)
# tensor(True) tensor(0.0438) tensor(0.0438)
# tensor(True) tensor(0.1338) tensor(0.1338)
# tensor(True) tensor(0.0103) tensor(0.0103)
# tensor(True) tensor(0.0206) tensor(0.0206)
# tensor(True) tensor(0.0035) tensor(0.0035)
# tensor(True) tensor(0.1552) tensor(0.1552)
# tensor(True) tensor(0.0074) tensor(0.0074)
# tensor(True) tensor(0.1246) tensor(0.1246)
# tensor(True) tensor(0.0111) tensor(0.0111)
# tensor(True) tensor(0.0429) tensor(0.0429)
# tensor(True) tensor(0.0712) tensor(0.0712)
# tensor(True) tensor(0.1869) tensor(0.1869)
# tensor(True) tensor(0.1113) tensor(0.1113)
# tensor(True) tensor(0.1050) tensor(0.1050)
# tensor(True) tensor(0.0805) tensor(0.0805)
# tensor(True) tensor(0.0017) tensor(0.0017)
# tensor(True) tensor(0.0781) tensor(0.0781)
# tensor(True) tensor(0.0938) tensor(0.0938)
# tensor(True) tensor(0.0533) tensor(0.0533)
# tensor(True) tensor(0.0070) tensor(0.0070)
# tensor(True) tensor(0.0638) tensor(0.0638)
# tensor(True) tensor(0.0138) tensor(0.0138)
# tensor(True) tensor(0.0611) tensor(0.0611)
# tensor(True) tensor(0.0119) tensor(0.0119)
# tensor(True) tensor(0.1524) tensor(0.1524)
# tensor(True) tensor(0.2073) tensor(0.2073)
# tensor(True) tensor(0.0060) tensor(0.0060)
# tensor(True) tensor(0.0018) tensor(0.0018)
# tensor(True) tensor(0.0080) tensor(0.0080)
# tensor(True) tensor(0.0094) tensor(0.0094)
# tensor(True) tensor(0.0072) tensor(0.0072)
# tensor(True) tensor(0.0039) tensor(0.0039)
# tensor(True) tensor(0.0803) tensor(0.0803)
# tensor(True) tensor(0.1072) tensor(0.1072)
# tensor(True) tensor(0.0482) tensor(0.0482)
# tensor(True) tensor(-0.0166) tensor(-0.0166)
# tensor(True) tensor(0.0249) tensor(0.0249)
# tensor(True) tensor(0.0172) tensor(0.0172)
# tensor(True) tensor(0.1779) tensor(0.1779)
# tensor(True) tensor(0.1747) tensor(0.1747)
# tensor(True) tensor(0.0630) tensor(0.0630)
# tensor(True) tensor(-0.0102) tensor(-0.0102)
# tensor(True) tensor(0.0328) tensor(0.0328)
# tensor(True) tensor(0.0203) tensor(0.0203)
# tensor(True) tensor(0.0154) tensor(0.0154)
# tensor(True) tensor(0.0185) tensor(0.0185)
# tensor(True) tensor(0.0052) tensor(0.0052)
# tensor(True) tensor(0.0548) tensor(0.0548)
# tensor(True) tensor(0.2782) tensor(0.2782)
# tensor(True) tensor(0.1475) tensor(0.1475)
# tensor(True) tensor(0.0277) tensor(0.0277)
# tensor(True) tensor(0.0373) tensor(0.0373)
# tensor(True) tensor(0.0144) tensor(0.0144)
# tensor(True) tensor(0.0123) tensor(0.0123)
# tensor(True) tensor(0.0704) tensor(0.0704)
# tensor(True) tensor(0.0398) tensor(0.0398)
# tensor(True) tensor(-0.0438) tensor(-0.0438)
# tensor(True) tensor(0.2161) tensor(0.2161)
# tensor(True) tensor(0.1203) tensor(0.1203)
# tensor(True) tensor(0.0754) tensor(0.0754)
# tensor(True) tensor(0.0864) tensor(0.0864)
# tensor(True) tensor(0.0340) tensor(0.0340)
# tensor(True) tensor(0.0022) tensor(0.0022)
# tensor(True) tensor(0.0019) tensor(0.0019)
# tensor(True) tensor(0.0007) tensor(0.0007)
# tensor(True) tensor(0.0155) tensor(0.0155)
# tensor(True) tensor(0.0540) tensor(0.0540)
# tensor(True) tensor(0.0332) tensor(0.0332)
# tensor(True) tensor(0.0145) tensor(0.0145)
# tensor(True) tensor(0.0738) tensor(0.0738)
# tensor(True) tensor(0.0441) tensor(0.0441)
# tensor(True) tensor(-0.0162) tensor(-0.0162)
# tensor(True) tensor(0.0225) tensor(0.0225)
# tensor(True) tensor(0.0161) tensor(0.0161)
# tensor(True) tensor(-0.1431) tensor(-0.1431)
# tensor(True) tensor(0.2450) tensor(0.2450)
# tensor(True) tensor(0.1706) tensor(0.1706)
# tensor(True) tensor(0.0069) tensor(0.0069)
# tensor(True) tensor(0.0070) tensor(0.0070)
# tensor(True) tensor(0.0017) tensor(0.0017)
# tensor(True) tensor(0.0398) tensor(0.0398)
# tensor(True) tensor(0.0604) tensor(0.0604)
# tensor(True) tensor(0.0233) tensor(0.0233)
# tensor(True) tensor(0.0381) tensor(0.0381)
# tensor(True) tensor(0.0590) tensor(0.0590)
# tensor(True) tensor(0.0267) tensor(0.0267)
# tensor(True) tensor(0.0458) tensor(0.0458)
# tensor(True) tensor(0.1399) tensor(0.1399)
# tensor(True) tensor(0.0673) tensor(0.0673)
# tensor(True) tensor(0.1838) tensor(0.1838)
# tensor(True) tensor(0.1831) tensor(0.1831)
# tensor(True) tensor(0.0490) tensor(0.0490)
# tensor(True) tensor(0.0186) tensor(0.0186)
# tensor(True) tensor(0.0985) tensor(0.0985)
# tensor(True) tensor(0.0646) tensor(0.0646)
# tensor(True) tensor(0.0009) tensor(0.0009)
# tensor(True) tensor(0.1271) tensor(0.1271)
# tensor(True) tensor(0.0787) tensor(0.0787)
# tensor(True) tensor(0.1197) tensor(0.1197)
# tensor(True) tensor(0.2488) tensor(0.2488)
# tensor(True) tensor(0.0964) tensor(0.0964)
# tensor(True) tensor(-0.0179) tensor(-0.0179)
# tensor(True) tensor(0.0709) tensor(0.0709)
# tensor(True) tensor(0.0495) tensor(0.0495)
# tensor(True) tensor(0.1365) tensor(0.1365)
# tensor(True) tensor(0.0934) tensor(0.0934)
# tensor(True) tensor(0.0331) tensor(0.0331)
# tensor(True) tensor(0.0003) tensor(0.0003)
# tensor(True) tensor(0.0067) tensor(0.0067)
# tensor(True) tensor(0.0037) tensor(0.0037)
# tensor(True) tensor(-0.0471) tensor(-0.0471)
# tensor(True) tensor(0.2772) tensor(0.2772)
# tensor(True) tensor(0.1955) tensor(0.1955)
# tensor(True) tensor(-0.0053) tensor(-0.0053)
# tensor(True) tensor(0.0254) tensor(0.0254)
# tensor(True) tensor(0.0141) tensor(0.0141)
# tensor(True) tensor(-0.0008) tensor(-0.0008)
# tensor(True) tensor(0.0943) tensor(0.0943)
# tensor(True) tensor(0.0603) tensor(0.0603)
# tensor(True) tensor(0.2156) tensor(0.2156)
# tensor(True) tensor(0.1263) tensor(0.1263)
# tensor(True) tensor(0.0360) tensor(0.0360)
# tensor(True) tensor(0.0160) tensor(0.0160)
# tensor(True) tensor(0.0673) tensor(0.0673)
# tensor(True) tensor(0.0413) tensor(0.0413)
# tensor(True) tensor(-0.0042) tensor(-0.0042)
# tensor(True) tensor(0.0753) tensor(0.0753)
# tensor(True) tensor(-0.0913) tensor(-0.0913)
# tensor(True) tensor(-0.0454) tensor(-0.0454)
# tensor(True) tensor(0.1829) tensor(0.1829)
# tensor(True) tensor(-0.0485) tensor(-0.0485)
# tensor(True) tensor(-0.0007) tensor(-0.0007)
# tensor(True) tensor(0.0184) tensor(0.0184)
# tensor(True) tensor(-0.0859) tensor(-0.0859)
# tensor(True) tensor(0.0266) tensor(0.0266)
# tensor(True) tensor(0.0302) tensor(0.0302)
# tensor(True) tensor(-0.0397) tensor(-0.0397)
# tensor(True) tensor(-0.1358) tensor(-0.1358)
# tensor(True) tensor(0.1649) tensor(0.1649)
# tensor(True) tensor(-0.1242) tensor(-0.1242)
# tensor(True) tensor(-0.1279) tensor(-0.1279)
# tensor(True) tensor(0.1969) tensor(0.1969)
# tensor(True) tensor(-0.2531) tensor(-0.2531)
# tensor(True) tensor(-0.0557) tensor(-0.0557)
# tensor(True) tensor(0.0258) tensor(0.0258)
# tensor(True) tensor(-0.1176) tensor(-0.1176)
# tensor(True) tensor(0.0080) tensor(0.0080)
# tensor(True) tensor(0.0189) tensor(0.0189)
# tensor(True) tensor(-0.0040) tensor(-0.0040)
# tensor(True) tensor(-0.0164) tensor(-0.0164)
# tensor(True) tensor(0.1436) tensor(0.1436)
# tensor(True) tensor(-0.1051) tensor(-0.1051)
# tensor(True) tensor(-0.0221) tensor(-0.0221)
# tensor(True) tensor(0.0231) tensor(0.0231)
# tensor(True) tensor(-0.0582) tensor(-0.0582)
# tensor(True) tensor(-0.0563) tensor(-0.0563)
# tensor(True) tensor(0.0097) tensor(0.0097)
# tensor(True) tensor(-0.1472) tensor(-0.1472)
# tensor(True) tensor(-0.0034) tensor(-0.0034)
# tensor(True) tensor(0.0003) tensor(0.0003)
# tensor(True) tensor(-0.0067) tensor(-0.0067)
# tensor(True) tensor(-0.1547) tensor(-0.1547)
# tensor(True) tensor(0.0777) tensor(0.0777)
# tensor(True) tensor(-0.0809) tensor(-0.0809)
# tensor(True) tensor(-0.0247) tensor(-0.0247)
# tensor(True) tensor(0.0519) tensor(0.0519)
# tensor(True) tensor(0.0139) tensor(0.0139)
# tensor(True) tensor(-0.0664) tensor(-0.0664)
# tensor(True) tensor(0.0639) tensor(0.0639)
# tensor(True) tensor(-0.0508) tensor(-0.0508)
# tensor(True) tensor(-0.0404) tensor(-0.0404)
# tensor(True) tensor(0.0580) tensor(0.0580)
# tensor(True) tensor(0.0153) tensor(0.0153)
# tensor(True) tensor(-0.0002) tensor(-0.0002)
# tensor(True) tensor(0.0003) tensor(0.0003)
# tensor(True) tensor(-0.0004) tensor(-0.0004)
# ...
# tensor(True) tensor(0.0360) tensor(0.0360)
# tensor(True) tensor(-0.0108) tensor(-0.0108)
# tensor(True) tensor(0.2018) tensor(0.2018)
# tensor(True) tensor(-0.1491) tensor(-0.1491)
# tensor(True) tensor(-0.0970) tensor(-0.0970)
# tensor(True) tensor(0.0015) tensor(0.0015)
# tensor(True) tensor(-0.0110) tensor(-0.0110)
# tensor(True) tensor(0.0745) tensor(0.0745)
# tensor(True) tensor(-0.0898) tensor(-0.0898)
# tensor(True) tensor(0.0063) tensor(0.0063)
# tensor(True) tensor(0.0334) tensor(0.0334)
# tensor(True) tensor(0.0017) tensor(0.0017)
# tensor(True) tensor(0.2281) tensor(0.2281)
# tensor(True) tensor(-0.1400) tensor(-0.1400)
# tensor(True) tensor(-0.0323) tensor(-0.0323)
# tensor(True) tensor(0.0953) tensor(0.0953)
# tensor(True) tensor(0.0256) tensor(0.0256)
# tensor(True) tensor(0.2545) tensor(0.2545)
# tensor(True) tensor(-0.1675) tensor(-0.1675)
# tensor(True) tensor(-0.0374) tensor(-0.0374)
# tensor(True) tensor(-0.0585) tensor(-0.0585)
# tensor(True) tensor(-0.0517) tensor(-0.0517)
# tensor(True) tensor(0.0791) tensor(0.0791)
# tensor(True) tensor(-0.0949) tensor(-0.0949)
# tensor(True) tensor(-0.0492) tensor(-0.0492)
# tensor(True) tensor(0.1153) tensor(0.1153)
# tensor(True) tensor(0.0290) tensor(0.0290)
# tensor(True) tensor(0.3029) tensor(0.3029)
# tensor(True) tensor(-0.1508) tensor(-0.1508)
# tensor(True) tensor(-0.0062) tensor(-0.0062)
# tensor(True) tensor(0.1002) tensor(0.1002)
# tensor(True) tensor(0.1639) tensor(0.1639)
# tensor(True) tensor(0.2009) tensor(0.2009)
# tensor(True) tensor(-0.2222) tensor(-0.2222)
# tensor(True) tensor(-0.0071) tensor(-0.0071)
# tensor(True) tensor(0.0111) tensor(0.0111)
# tensor(True) tensor(0.0083) tensor(0.0083)
# tensor(True) tensor(0.0150) tensor(0.0150)
# tensor(True) tensor(-0.0123) tensor(-0.0123)
# tensor(True) tensor(-0.0950) tensor(-0.0950)
# tensor(True) tensor(0.0749) tensor(0.0749)
# tensor(True) tensor(-0.0422) tensor(-0.0422)
# tensor(True) tensor(0.2917) tensor(0.2917)
# tensor(True) tensor(-0.1249) tensor(-0.1249)
# tensor(True) tensor(0.2953) tensor(0.2953)
# tensor(True) tensor(0.1193) tensor(0.1193)
# tensor(True) tensor(-0.1660) tensor(-0.1660)
# tensor(True) tensor(0.1439) tensor(0.1439)
# tensor(True) tensor(0.0606) tensor(0.0606)
# tensor(True) tensor(0.0039) tensor(0.0039)
# tensor(True) tensor(0.0034) tensor(0.0034)
# tensor(True) tensor(-0.0017) tensor(-0.0017)
# tensor(True) tensor(0.0039) tensor(0.0039)
# tensor(True) tensor(-0.0032) tensor(-0.0032)
# tensor(True) tensor(0.0905) tensor(0.0905)
# tensor(True) tensor(0.0030) tensor(0.0030)
# tensor(True) tensor(-0.0518) tensor(-0.0518)
# tensor(True) tensor(0.0028) tensor(0.0028)
# tensor(True) tensor(0.0042) tensor(0.0042)
# tensor(True) tensor(0.2000) tensor(0.2000)
# tensor(True) tensor(0.0126) tensor(0.0126)
# tensor(True) tensor(-0.1062) tensor(-0.1062)
# tensor(True) tensor(0.0089) tensor(0.0089)
# tensor(True) tensor(-0.0660) tensor(-0.0660)
# tensor(True) tensor(0.0392) tensor(0.0392)
# tensor(True) tensor(0.0330) tensor(0.0330)
# tensor(True) tensor(-0.0170) tensor(-0.0170)
# tensor(True) tensor(0.0376) tensor(0.0376)
# tensor(True) tensor(-0.0286) tensor(-0.0286)
# tensor(True) tensor(0.1240) tensor(0.1240)
# tensor(True) tensor(0.0353) tensor(0.0353)
# tensor(True) tensor(-0.0580) tensor(-0.0580)
# tensor(True) tensor(0.0351) tensor(0.0351)
# tensor(True) tensor(-0.0972) tensor(-0.0972)
# tensor(True) tensor(0.0062) tensor(0.0062)
# tensor(True) tensor(0.0035) tensor(0.0035)
# tensor(True) tensor(-0.0038) tensor(-0.0038)
# tensor(True) tensor(0.0044) tensor(0.0044)
# tensor(True) tensor(0.0049) tensor(0.0049)
# tensor(True) tensor(0.3243) tensor(0.3243)
# tensor(True) tensor(0.0729) tensor(0.0729)
# tensor(True) tensor(-0.1977) tensor(-0.1977)
# tensor(True) tensor(0.0947) tensor(0.0947)
# tensor(True) tensor(0.1747) tensor(0.1747)
# tensor(True) tensor(0.1104) tensor(0.1104)
# tensor(True) tensor(0.0124) tensor(0.0124)
# tensor(True) tensor(-0.0525) tensor(-0.0525)
# tensor(True) tensor(0.0081) tensor(0.0081)
# tensor(True) tensor(-0.0914) tensor(-0.0914)
# tensor(True) tensor(0.1637) tensor(0.1637)
# tensor(True) tensor(0.0598) tensor(0.0598)
# tensor(True) tensor(-0.0879) tensor(-0.0879)
# tensor(True) tensor(0.0694) tensor(0.0694)
# tensor(True) tensor(-0.0104) tensor(-0.0104)
# tensor(True) tensor(0.1005) tensor(0.1005)
# tensor(True) tensor(0.0376) tensor(0.0376)
# tensor(True) tensor(-0.0546) tensor(-0.0546)
# tensor(True) tensor(0.0441) tensor(0.0441)
# tensor(True) tensor(0.0002) tensor(0.0002)
# tensor(True) tensor(0.0660) tensor(0.0660)
# tensor(True) tensor(0.1327) tensor(0.1327)
# tensor(True) tensor(-0.0354) tensor(-0.0354)
# tensor(True) tensor(0.1632) tensor(0.1632)
# tensor(True) tensor(0.0704) tensor(0.0704)
# tensor(True) tensor(0.1095) tensor(0.1095)
# tensor(True) tensor(0.0547) tensor(0.0547)
# tensor(True) tensor(-0.0620) tensor(-0.0620)
# tensor(True) tensor(0.0666) tensor(0.0666)
# tensor(True) tensor(0.0339) tensor(0.0339)
# tensor(True) tensor(0.0401) tensor(0.0401)
# tensor(True) tensor(0.0601) tensor(0.0601)
# tensor(True) tensor(-0.0159) tensor(-0.0159)
# tensor(True) tensor(0.0702) tensor(0.0702)
# tensor(True) tensor(-0.0259) tensor(-0.0259)
# tensor(True) tensor(0.0374) tensor(0.0374)
# tensor(True) tensor(0.0009) tensor(0.0009)
# tensor(True) tensor(-0.0247) tensor(-0.0247)
# tensor(True) tensor(0.0026) tensor(0.0026)
# tensor(True) tensor(0.0327) tensor(0.0327)
# tensor(True) tensor(0.1194) tensor(0.1194)
# tensor(True) tensor(0.1253) tensor(0.1253)
# tensor(True) tensor(-0.0617) tensor(-0.0617)
# tensor(True) tensor(0.1509) tensor(0.1509)
# tensor(True) tensor(0.0252) tensor(0.0252)
# tensor(True) tensor(0.0630) tensor(0.0630)
# tensor(True) tensor(0.0489) tensor(0.0489)
# tensor(True) tensor(-0.0358) tensor(-0.0358)
# tensor(True) tensor(0.0601) tensor(0.0601)
# tensor(True) tensor(0.0329) tensor(0.0329)
# tensor(True) tensor(0.0081) tensor(0.0081)
# tensor(True) tensor(0.0234) tensor(0.0234)
# tensor(True) tensor(-0.0028) tensor(-0.0028)
# tensor(True) tensor(0.0280) tensor(0.0280)
# tensor(True) tensor(-0.0017) tensor(-0.0017)
# tensor(True) tensor(0.0181) tensor(0.0181)
# tensor(True) tensor(0.0085) tensor(0.0085)
# tensor(True) tensor(-0.0117) tensor(-0.0117)
# tensor(True) tensor(0.0112) tensor(0.0112)
# tensor(True) tensor(0.0191) tensor(0.0191)
# tensor(True) tensor(0.0017) tensor(0.0017)
# tensor(True) tensor(0.0004) tensor(0.0004)
# tensor(True) tensor(-0.0010) tensor(-0.0010)
# tensor(True) tensor(0.0004) tensor(0.0004)
# tensor(True) tensor(0.0003) tensor(0.0003)
# tensor(True) tensor(0.1586) tensor(0.1586)
# tensor(True) tensor(0.1583) tensor(0.1583)
# tensor(True) tensor(-0.0743) tensor(-0.0743)
# tensor(True) tensor(0.1859) tensor(0.1859)
# tensor(True) tensor(-0.0451) tensor(-0.0451)
# tensor(True) tensor(0.1921) tensor(0.1921)
# tensor(True) tensor(0.1225) tensor(0.1225)
# tensor(True) tensor(-0.0874) tensor(-0.0874)
# tensor(True) tensor(0.1374) tensor(0.1374)
# tensor(True) tensor(-0.1281) tensor(-0.1281)
# tensor(True) tensor(0.2966) tensor(0.2966)
# tensor(True) tensor(0.0942) tensor(0.0942)
# tensor(True) tensor(-0.1652) tensor(-0.1652)
# tensor(True) tensor(0.1118) tensor(0.1118)
# tensor(True) tensor(0.0286) tensor(0.0286)
# tensor(True) tensor(0.0694) tensor(0.0694)
# tensor(True) tensor(0.0798) tensor(0.0798)
# tensor(True) tensor(-0.0361) tensor(-0.0361)
# tensor(True) tensor(0.0965) tensor(0.0965)
# tensor(True) tensor(0.0219) tensor(0.0219)
# tensor(True) tensor(0.1858) tensor(0.1858)
# tensor(True) tensor(0.0730) tensor(0.0730)
# tensor(True) tensor(-0.1204) tensor(-0.1204)
# tensor(True) tensor(0.0973) tensor(0.0973)
# tensor(True) tensor(0.1902) tensor(0.1902)
# tensor(True) tensor(0.1624) tensor(0.1624)
# tensor(True) tensor(0.1492) tensor(0.1492)
# tensor(True) tensor(-0.1013) tensor(-0.1013)
# tensor(True) tensor(0.1891) tensor(0.1891)
# tensor(True) tensor(0.1881) tensor(0.1881)
# tensor(True) tensor(0.1765) tensor(0.1765)
# tensor(True) tensor(0.0507) tensor(0.0507)
# tensor(True) tensor(-0.0986) tensor(-0.0986)
# tensor(True) tensor(0.0600) tensor(0.0600)
# tensor(True) tensor(0.0161) tensor(0.0161)
# tensor(True) tensor(0.1033) tensor(0.1033)
# tensor(True) tensor(0.1488) tensor(0.1488)
# tensor(True) tensor(-0.0425) tensor(-0.0425)
# tensor(True) tensor(0.1745) tensor(0.1745)
# tensor(True) tensor(-0.0547) tensor(-0.0547)
# tensor(True) tensor(0.2273) tensor(0.2273)
# tensor(True) tensor(0.1338) tensor(0.1338)
# tensor(True) tensor(-0.1305) tensor(-0.1305)
# tensor(True) tensor(0.1646) tensor(0.1646)
# tensor(True) tensor(0.1017) tensor(0.1017)
# tensor(True) tensor(0.1542) tensor(0.1542)
# tensor(True) tensor(0.2202) tensor(0.2202)
# tensor(True) tensor(-0.0777) tensor(-0.0777)
# tensor(True) tensor(0.2665) tensor(0.2665)
# tensor(True) tensor(0.0540) tensor(0.0540)
# tensor(True) tensor(0.0117) tensor(0.0117)
# tensor(True) tensor(0.0040) tensor(0.0040)
# tensor(True) tensor(-0.0065) tensor(-0.0065)
# tensor(True) tensor(0.0048) tensor(0.0048)
# tensor(True) tensor(0.0018) tensor(0.0018)
# tensor(True) tensor(0.2576) tensor(0.2576)
# tensor(True) tensor(0.0739) tensor(0.0739)
# tensor(True) tensor(-0.1340) tensor(-0.1340)
# tensor(True) tensor(0.0816) tensor(0.0816)
# tensor(True) tensor(-0.0722) tensor(-0.0722)
# tensor(True) tensor(0.0049) tensor(0.0049)
# tensor(True) tensor(0.2443) tensor(0.2443)
# tensor(True) tensor(-0.0145) tensor(-0.0145)
# tensor(True) tensor(-0.0541) tensor(-0.0541)
# tensor(True) tensor(-0.1218) tensor(-0.1218)
# tensor(True) tensor(0.0239) tensor(0.0239)
# tensor(True) tensor(0.2103) tensor(0.2103)
# tensor(True) tensor(0.0284) tensor(0.0284)
# tensor(True) tensor(-0.1559) tensor(-0.1559)
# tensor(True) tensor(-0.0454) tensor(-0.0454)
# tensor(True) tensor(0.0040) tensor(0.0040)
# tensor(True) tensor(0.0106) tensor(0.0106)
# tensor(True) tensor(0.0018) tensor(0.0018)
# tensor(True) tensor(-0.0079) tensor(-0.0079)
# tensor(True) tensor(-0.0160) tensor(-0.0160)
# tensor(True) tensor(0.0391) tensor(0.0391)
# tensor(True) tensor(0.1601) tensor(0.1601)
# tensor(True) tensor(0.0551) tensor(0.0551)
# tensor(True) tensor(-0.0837) tensor(-0.0837)
# tensor(True) tensor(-0.0536) tensor(-0.0536)
# tensor(True) tensor(0.0993) tensor(0.0993)
# tensor(True) tensor(0.1739) tensor(0.1739)
# tensor(True) tensor(0.1334) tensor(0.1334)
# tensor(True) tensor(-0.1354) tensor(-0.1354)
# tensor(True) tensor(-0.1173) tensor(-0.1173)
# tensor(True) tensor(0.0516) tensor(0.0516)
# tensor(True) tensor(0.2042) tensor(0.2042)
# tensor(True) tensor(0.0637) tensor(0.0637)
# tensor(True) tensor(-0.1846) tensor(-0.1846)
# tensor(True) tensor(-0.0720) tensor(-0.0720)
# tensor(True) tensor(0.0204) tensor(0.0204)
# tensor(True) tensor(0.0686) tensor(0.0686)
# tensor(True) tensor(0.0325) tensor(0.0325)
# tensor(True) tensor(0.0024) tensor(0.0024)
# tensor(True) tensor(-0.0270) tensor(-0.0270)
# tensor(True) tensor(-5.2177e-05) tensor(-5.2177e-05)
# tensor(True) tensor(0.0009) tensor(0.0009)
# tensor(True) tensor(-7.7748e-05) tensor(-7.7748e-05)
# tensor(True) tensor(-0.0003) tensor(-0.0003)
# tensor(True) tensor(-0.0001) tensor(-0.0001)
# tensor(True) tensor(-0.0513) tensor(-0.0513)
# tensor(True) tensor(0.1588) tensor(0.1588)
# tensor(True) tensor(-0.0898) tensor(-0.0898)
# tensor(True) tensor(-0.0216) tensor(-0.0216)
# tensor(True) tensor(-0.0438) tensor(-0.0438)
# tensor(True) tensor(0.0034) tensor(0.0034)
# tensor(True) tensor(0.2584) tensor(0.2584)
# tensor(True) tensor(-0.0003) tensor(-0.0003)
# tensor(True) tensor(-0.1679) tensor(-0.1679)
# tensor(True) tensor(-0.0347) tensor(-0.0347)
# tensor(True) tensor(-0.0060) tensor(-0.0060)
# tensor(True) tensor(0.0469) tensor(0.0469)
# tensor(True) tensor(-0.0109) tensor(-0.0109)
# tensor(True) tensor(-0.0165) tensor(-0.0165)
# tensor(True) tensor(-0.0097) tensor(-0.0097)
# tensor(True) tensor(-0.0012) tensor(-0.0012)
# tensor(True) tensor(0.0124) tensor(0.0124)
# tensor(True) tensor(-0.0036) tensor(-0.0036)
# tensor(True) tensor(-0.0060) tensor(-0.0060)
# tensor(True) tensor(-0.0061) tensor(-0.0061)
# tensor(True) tensor(0.0061) tensor(0.0061)
# tensor(True) tensor(0.0701) tensor(0.0701)
# tensor(True) tensor(0.0027) tensor(0.0027)
# tensor(True) tensor(-0.0410) tensor(-0.0410)
# tensor(True) tensor(-0.0299) tensor(-0.0299)
# tensor(True) tensor(-0.0035) tensor(-0.0035)
# tensor(True) tensor(0.1710) tensor(0.1710)
# tensor(True) tensor(-0.0181) tensor(-0.0181)
# tensor(True) tensor(-0.0817) tensor(-0.0817)
# tensor(True) tensor(-0.0580) tensor(-0.0580)
# tensor(True) tensor(0.0251) tensor(0.0251)
# tensor(True) tensor(0.0701) tensor(0.0701)
# tensor(True) tensor(0.0261) tensor(0.0261)
# tensor(True) tensor(-0.0657) tensor(-0.0657)
# tensor(True) tensor(-0.0501) tensor(-0.0501)
# tensor(True) tensor(-0.0162) tensor(-0.0162)
# tensor(True) tensor(0.2857) tensor(0.2857)
# tensor(True) tensor(-0.0578) tensor(-0.0578)
# tensor(True) tensor(-0.1136) tensor(-0.1136)
# tensor(True) tensor(-0.1362) tensor(-0.1362)
# tensor(True) tensor(0.0544) tensor(0.0544)
# tensor(True) tensor(0.3847) tensor(0.3847)
# tensor(True) tensor(0.0674) tensor(0.0674)
# tensor(True) tensor(-0.1568) tensor(-0.1568)
# tensor(True) tensor(-0.1348) tensor(-0.1348)
# tensor(True) tensor(-0.0190) tensor(-0.0190)
# tensor(True) tensor(0.2243) tensor(0.2243)
# tensor(True) tensor(-0.0299) tensor(-0.0299)
# tensor(True) tensor(-0.1104) tensor(-0.1104)
# tensor(True) tensor(-0.0172) tensor(-0.0172)
# tensor(True) tensor(-0.0433) tensor(-0.0433)
# tensor(True) tensor(0.1254) tensor(0.1254)
# tensor(True) tensor(-0.1022) tensor(-0.1022)
# tensor(True) tensor(-0.0498) tensor(-0.0498)
# tensor(True) tensor(-0.1068) tensor(-0.1068)
# tensor(True) tensor(6.4716e-05) tensor(6.4717e-05)
# tensor(True) tensor(0.0571) tensor(0.0571)
# tensor(True) tensor(-0.0171) tensor(-0.0171)
# tensor(True) tensor(-0.0482) tensor(-0.0482)
# tensor(True) tensor(-0.0540) tensor(-0.0540)
# tensor(True) tensor(-0.0077) tensor(-0.0077)
# tensor(True) tensor(0.0484) tensor(0.0484)
# tensor(True) tensor(-0.0155) tensor(-0.0155)
# tensor(True) tensor(-0.0178) tensor(-0.0178)
# tensor(True) tensor(-0.0150) tensor(-0.0150)
# tensor(True) tensor(0.0076) tensor(0.0076)
# tensor(True) tensor(0.0544) tensor(0.0544)
# tensor(True) tensor(0.0009) tensor(0.0009)
# tensor(True) tensor(-0.0355) tensor(-0.0355)
# tensor(True) tensor(-0.0413) tensor(-0.0413)
# tensor(True) tensor(-0.0048) tensor(-0.0048)
# tensor(True) tensor(0.1120) tensor(0.1120)
# tensor(True) tensor(-0.0063) tensor(-0.0063)
# tensor(True) tensor(-0.0073) tensor(-0.0073)
# tensor(True) tensor(-0.0229) tensor(-0.0229)
# tensor(True) tensor(-0.0074) tensor(-0.0074)
# tensor(True) tensor(0.0518) tensor(0.0518)
# tensor(True) tensor(-0.0272) tensor(-0.0272)
# tensor(True) tensor(-0.0193) tensor(-0.0193)
# tensor(True) tensor(-0.0537) tensor(-0.0537)
# tensor(True) tensor(0.0348) tensor(0.0348)
# tensor(True) tensor(0.1034) tensor(0.1034)
# tensor(True) tensor(0.0415) tensor(0.0415)
# tensor(True) tensor(-0.0758) tensor(-0.0758)
# tensor(True) tensor(-0.0598) tensor(-0.0598)
# tensor(True) tensor(-0.0160) tensor(-0.0160)
# tensor(True) tensor(0.1715) tensor(0.1715)
# tensor(True) tensor(-0.0430) tensor(-0.0430)
# tensor(True) tensor(0.0590) tensor(0.0590)
# tensor(True) tensor(-0.1167) tensor(-0.1167)
# tensor(True) tensor(0.0156) tensor(0.0156)
# tensor(True) tensor(0.0813) tensor(0.0813)
# tensor(True) tensor(0.0104) tensor(0.0104)
# tensor(True) tensor(-0.0442) tensor(-0.0442)
# tensor(True) tensor(-0.0589) tensor(-0.0589)
# tensor(True) tensor(0.0128) tensor(0.0128)
# tensor(True) tensor(0.2311) tensor(0.2311)
# tensor(True) tensor(0.0001) tensor(0.0001)
# tensor(True) tensor(-0.0598) tensor(-0.0598)
# tensor(True) tensor(-0.1128) tensor(-0.1128)
# tensor(True) tensor(-0.0238) tensor(-0.0238)
# tensor(True) tensor(0.0797) tensor(0.0797)
# tensor(True) tensor(-0.0517) tensor(-0.0517)
# tensor(True) tensor(-0.0194) tensor(-0.0194)
# tensor(True) tensor(-0.0501) tensor(-0.0501)
# tensor(True) tensor(-0.0186) tensor(-0.0186)
# tensor(True) tensor(0.2511) tensor(0.2511)
# tensor(True) tensor(-0.0703) tensor(-0.0703)
# tensor(True) tensor(-0.0791) tensor(-0.0791)
# tensor(True) tensor(-0.1645) tensor(-0.1645)
# tensor(True) tensor(0.0049) tensor(0.0049)
# tensor(True) tensor(0.0186) tensor(0.0186)
# tensor(True) tensor(0.0062) tensor(0.0062)
# tensor(True) tensor(-0.0127) tensor(-0.0127)
# tensor(True) tensor(-0.0078) tensor(-0.0078)
# tensor(True) tensor(0.0178) tensor(0.0178)
# tensor(True) tensor(0.0404) tensor(0.0404)
# tensor(True) tensor(0.0287) tensor(0.0287)
# tensor(True) tensor(0.0082) tensor(0.0082)
# tensor(True) tensor(-0.0191) tensor(-0.0191)

# %%
a_u_cnt = []
b_u_cnt = []
fiber_cnt = []
i_cnt = []
step = 32
i = 0
fiber_cnt_pattern = {}
while(i< uvuv_i_out.dim):
    u_in1 = cg_dummy_kij[i:i+step].nonzero()[:,1].unique()
    u_in2 = cg_dummy_kij[i:i+step].nonzero()[:,2].unique()


    l_a_u_cnt = (cg_dummy_kij[i:i+step].nonzero()[:,1].unique().numel())
    l_b_u_cnt = (cg_dummy_kij[i:i+step].nonzero()[:,2].unique().numel())
    l_fiber_cnt = (cg_dummy_kij[i:i+step].nonzero().shape[0])

    pattern = per_out_fiber[i:i+step].tolist()

    # print([pattern[0]]*len(pattern))
    

    # print(list(itertools.chain.from_iterable(([pattern[0:3]]*len(pattern))))[0:len(pattern)])
    # print(list(itertools.chain.from_iterable(([pattern[0:5]]*len(pattern))))[0:len(pattern)])
    
    if ([pattern[0]]*len(pattern) == pattern):
        pattern_tuple = (1, pattern[0])
    elif (list(itertools.chain.from_iterable(([pattern[0:3]]*len(pattern))))[0:len(pattern)] == pattern):
        pattern_tuple = (3, pattern[0:3])
    elif (list(itertools.chain.from_iterable(([pattern[0:5]]*len(pattern))))[0:len(pattern)] == pattern):
        pattern_tuple = (5, pattern[0:5])
    elif (list(itertools.chain.from_iterable(([pattern[0:7]]*len(pattern))))[0:len(pattern)] == pattern):
        pattern_tuple = (7, pattern[0:7])
    else:
        print("bad")
    

    if str(pattern_tuple) not in fiber_cnt_pattern:
        fiber_cnt_pattern[str(pattern_tuple)] = []
    fiber_cnt_pattern[str(pattern_tuple)].append(i//32)
    # # plt.scatter(cg_dummy_kij[i:i+step].nonzero()[:,0], cg_dummy_kij[i:i+32].nonzero()[:,1])
    # # plt.show()
    # # plt.close()
    # if(l_a_u_cnt > 60):
    #     l_a_u_cnt = (cg_dummy_kij[i:i+step//2].nonzero()[:,1].unique().numel())
    #     l_b_u_cnt = (cg_dummy_kij[i:i+step//2].nonzero()[:,2].unique().numel())
    #     l_fiber_cnt = (cg_dummy_kij[i:i+step//2].nonzero().shape[0])
    #     if(l_a_u_cnt > 60):
    #         l_a_u_cnt = (cg_dummy_kij[i:i+step//4].nonzero()[:,1].unique().numel())
    #         l_b_u_cnt = (cg_dummy_kij[i:i+step//4].nonzero()[:,2].unique().numel())
    #         l_fiber_cnt = (cg_dummy_kij[i:i+step//4].nonzero().shape[0])

    #         a_u_cnt.append(l_a_u_cnt)
    #         b_u_cnt.append(l_b_u_cnt)
    #         fiber_cnt.append(l_fiber_cnt)
    #         i_cnt.append(step//4)
    #         i += step//4
    #     else:
    #         a_u_cnt.append(l_a_u_cnt)
    #         b_u_cnt.append(l_b_u_cnt)
    #         fiber_cnt.append(l_fiber_cnt)
    #         i_cnt.append(step//2)
    #         i += step//2
    # else:
    a_u_cnt.append(l_a_u_cnt)
    b_u_cnt.append(l_b_u_cnt)
    fiber_cnt.append(l_fiber_cnt)
    i_cnt.append(step)
    i += step

# %%
smem_size = []
for a, b, f, i in zip(a_u_cnt, b_u_cnt, fiber_cnt, i_cnt):
    smem_size.append((32 * (a+b+i+i) +f) * 4 )
    print(a,b,f,i)
# Out:
# 32 1 32 32
# 96 3 96 32
# 160 5 160 32
# 32 1 32 32
# 160 5 160 32
# 96 3 96 32
# 11 3 32 32
# 12 3 32 32
# 11 3 32 32
# 33 3 64 32
# 34 3 64 32
# 33 3 64 32
# 55 3 117 32
# 58 3 118 32
# 55 3 117 32
# 32 1 32 32
# 32 1 32 32
# 32 1 32 32
# 33 5 117 32
# 36 5 118 32
# 33 5 117 32
# 55 5 170 32
# 60 5 172 32
# 55 5 170 32
# 11 3 32 32
# 12 3 32 32
# 11 3 32 32
# 32 1 32 32
# 32 1 32 32
# 32 1 32 32
# 33 5 117 32
# 36 5 118 32
# 33 5 117 32
# 55 5 170 32
# 60 5 172 32
# 55 5 170 32
# 33 3 64 32
# 34 3 64 32
# 33 3 64 32
# 55 3 117 32
# 58 3 118 32
# 55 3 117 32
# 7 5 32 32
# 7 5 32 32
# 8 5 32 32
# 7 5 32 32
# 7 5 32 32
# 21 3 70 32
# 21 3 71 32
# 22 3 70 32
# 21 3 71 32
# 21 3 70 32
# 35 3 103 32
# 35 3 102 32
# 36 3 102 32
# 35 3 102 32
# 35 3 103 32
# 21 5 103 32
# 21 5 102 32
# 24 5 102 32
# 21 5 102 32
# 21 5 103 32
# 32 1 32 32
# 32 1 32 32
# 32 1 32 32
# 32 1 32 32
# 32 1 32 32
# 35 5 160 32
# 35 5 161 32
# 38 5 158 32
# 35 5 161 32
# 35 5 160 32
# 7 5 32 32
# 7 5 32 32
# 8 5 32 32
# 7 5 32 32
# 7 5 32 32
# 21 5 103 32
# 21 5 102 32
# 24 5 102 32
# 21 5 102 32
# 21 5 103 32
# 32 1 32 32
# 32 1 32 32
# 32 1 32 32
# 32 1 32 32
# 32 1 32 32
# 35 5 160 32
# 35 5 161 32
# 38 5 158 32
# 35 5 161 32
# 35 5 160 32
# 21 3 70 32
# 21 3 71 32
# 22 3 70 32
# 21 3 71 32
# 21 3 70 32
# 35 3 103 32
# 35 3 102 32
# 36 3 102 32
# 35 3 102 32
# 35 3 103 32

# %%
max(smem_size)
# Out:
# 29952
